# %%
# !pip install pandas

import pandas as pd
import os
os.chdir(r"H:\&문체부 공모전&")
df=pd.read_csv("KOBIS_월별박스오피스_230506.csv")
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df1 = df.iloc[7:568].reset_index(drop=True)
df1.head()
# Out:
#   ■ 월별 박스오피스          Unnamed: 1  Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0          1               범죄도시3  2023-05-31  87,130,311,881      60.0%
# 1          2                엘리멘탈  2023-06-14  16,661,492,941      11.5%
# 2          3      트랜스포머: 비스트의 서막  2023-06-06   7,731,747,754       5.3%
# 3          4                 플래시  2023-06-14   6,527,899,642       4.5%
# 4          5  스파이더맨: 어크로스 더 유니버스  2023-06-21   5,309,163,912       3.7%
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0  98,486,705,237  8,745,222  9,969,400      2,582    253,403          한국
# 1  16,668,970,941  1,691,732  1,692,554      1,331     62,632          미국
# 2   7,731,747,754    764,377    764,377      1,123     44,855          미국
# 3   6,527,899,642    614,030    614,030      1,258     41,890          미국
# 4   5,309,163,912    497,687    497,687      1,103     29,552          미국
#
#   Unnamed: 11                            Unnamed: 12
# ...

# %%
df1.tail()
# Out:
#     ■ 월별 박스오피스   Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4      Unnamed: 5  \
# 556        556  밀라노 두오모 콘서트  2022-01-07          0       0.0%               0
# 557        556    육사오(6/45)  2022-08-24          0       0.0%  19,791,780,880
# 558        556           애월  2019-09-26          0       0.0%               0
# 559        556       시집가는 날  1957-02-11          0       0.0%               0
# 560        556     나의 결혼원정기  2005-11-23          0       0.0%               0
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 556          0          0          1          1        이탈리아        이탈리아
# 557          0  1,980,856          1          1          한국          한국
# 558          0          0          1          1          한국          한국
# 559          0          0          1          2          한국          한국
# 560          0          0          1          2          한국          한국
#
#                Unnamed: 12
# 556                   일미디어
# ...

# %%
df2 = df.iloc[578:-1].reset_index(drop=True)
df2.head()
# Out:
#   ■ 월별 박스오피스                  Unnamed: 1  Unnamed: 2      Unnamed: 3  \
# 0          1       가디언즈 오브 갤럭시: Volume 3  2023-05-03  41,558,564,678
# 1          2           분노의 질주: 라이드 오어 다이  2023-05-17  16,994,798,760
# 2          3                 슈퍼 마리오 브라더스  2023-04-26  15,203,394,429
# 3          4                       범죄도시3  2023-05-31  11,356,393,356
# 4          5  극장판 짱구는 못말려: 동물소환 닌자 배꼽수비대  2023-05-04   6,793,684,949
#
#   Unnamed: 4      Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0      35.0%  41,558,564,678  3,936,452  3,936,452      1,819    139,717
# 1      14.3%  16,994,798,760  1,624,933  1,624,933      1,731     82,524
# 2      12.8%  22,924,703,237  1,559,739  2,328,838      1,576     60,940
# 3       9.6%  11,356,393,356  1,224,178  1,224,178      2,352     15,487
# 4       5.7%   6,831,105,825    685,661    688,746        844     26,670
#
#   Unnamed: 10 Unnamed: 11                            Unnamed: 12
# ...

# %%
df2.tail()
# Out:
#     ■ 월별 박스오피스                    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 566        553                      무화과나무 아래        NaN          0       0.0%
# 567        553                           마콩고        NaN          0       0.0%
# 568        553                           탈리야        NaN          0       0.0%
# 569        553                         프레지던트        NaN          0       0.0%
# 570        553  2023 아프리카영화제: 소년들의 거짓말+가나단편선        NaN          0       0.0%
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 566          0          0          0          1          4          기타
# 567          0          0          0          1          4          기타
# 568          0          0          0          1          4          케냐
# 569          0          0          0          1          4          기타
# 570          0          0          0          1          4          기타
#
#     Unnamed: 11 Unnamed: 12
# 566          기타         NaN
# ...

# %%
df1["month"]="23.06"
df1.head()
# Out:
#   ■ 월별 박스오피스          Unnamed: 1  Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0          1               범죄도시3  2023-05-31  87,130,311,881      60.0%
# 1          2                엘리멘탈  2023-06-14  16,661,492,941      11.5%
# 2          3      트랜스포머: 비스트의 서막  2023-06-06   7,731,747,754       5.3%
# 3          4                 플래시  2023-06-14   6,527,899,642       4.5%
# 4          5  스파이더맨: 어크로스 더 유니버스  2023-06-21   5,309,163,912       3.7%
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0  98,486,705,237  8,745,222  9,969,400      2,582    253,403          한국
# 1  16,668,970,941  1,691,732  1,692,554      1,331     62,632          미국
# 2   7,731,747,754    764,377    764,377      1,123     44,855          미국
# 3   6,527,899,642    614,030    614,030      1,258     41,890          미국
# 4   5,309,163,912    497,687    497,687      1,103     29,552          미국
#
#   Unnamed: 11                            Unnamed: 12  month
# ...

# %%
df1.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df1.head()
# Out:
#   ranking          movie_name release_date           sales sales_percentage  \
# 0       1               범죄도시3   2023-05-31  87,130,311,881            60.0%
# 1       2                엘리멘탈   2023-06-14  16,661,492,941            11.5%
# 2       3      트랜스포머: 비스트의 서막   2023-06-06   7,731,747,754             5.3%
# 3       4                 플래시   2023-06-14   6,527,899,642             4.5%
# 4       5  스파이더맨: 어크로스 더 유니버스   2023-06-21   5,309,163,912             3.7%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0   98,486,705,237  8,745,222           9,969,400        2,582    253,403
# 1   16,668,970,941  1,691,732           1,692,554        1,331     62,632
# 2    7,731,747,754    764,377             764,377        1,123     44,855
# 3    6,527,899,642    614,030             614,030        1,258     41,890
# 4    5,309,163,912    497,687             497,687        1,103     29,552
#
# ...

# %%
df2["month"]="23.05"
df2.head()
# Out:
#   ■ 월별 박스오피스                  Unnamed: 1  Unnamed: 2      Unnamed: 3  \
# 0          1       가디언즈 오브 갤럭시: Volume 3  2023-05-03  41,558,564,678
# 1          2           분노의 질주: 라이드 오어 다이  2023-05-17  16,994,798,760
# 2          3                 슈퍼 마리오 브라더스  2023-04-26  15,203,394,429
# 3          4                       범죄도시3  2023-05-31  11,356,393,356
# 4          5  극장판 짱구는 못말려: 동물소환 닌자 배꼽수비대  2023-05-04   6,793,684,949
#
#   Unnamed: 4      Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0      35.0%  41,558,564,678  3,936,452  3,936,452      1,819    139,717
# 1      14.3%  16,994,798,760  1,624,933  1,624,933      1,731     82,524
# 2      12.8%  22,924,703,237  1,559,739  2,328,838      1,576     60,940
# 3       9.6%  11,356,393,356  1,224,178  1,224,178      2,352     15,487
# 4       5.7%   6,831,105,825    685,661    688,746        844     26,670
#
#   Unnamed: 10 Unnamed: 11                            Unnamed: 12  month
# ...

# %%
df2.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df2.head()
# Out:
#   ranking                  movie_name release_date           sales  \
# 0       1       가디언즈 오브 갤럭시: Volume 3   2023-05-03  41,558,564,678
# 1       2           분노의 질주: 라이드 오어 다이   2023-05-17  16,994,798,760
# 2       3                 슈퍼 마리오 브라더스   2023-04-26  15,203,394,429
# 3       4                       범죄도시3   2023-05-31  11,356,393,356
# 4       5  극장판 짱구는 못말려: 동물소환 닌자 배꼽수비대   2023-05-04   6,793,684,949
#
#   sales_percentage cumulative_sales   audience cumulative_audience  \
# 0            35.0%   41,558,564,678  3,936,452           3,936,452
# 1            14.3%   16,994,798,760  1,624,933           1,624,933
# 2            12.8%   22,924,703,237  1,559,739           2,328,838
# 3             9.6%   11,356,393,356  1,224,178           1,224,178
# 4             5.7%    6,831,105,825    685,661             688,746
#
#   screen_count show_count main_country country  \
# 0        1,819    139,717           미국      미국
# 1        1,731     82,524           미국      미국
# ...

# %%
df = pd.concat([df2, df1])
df.head()
# Out:
#   ranking                  movie_name release_date           sales  \
# 0       1       가디언즈 오브 갤럭시: Volume 3   2023-05-03  41,558,564,678
# 1       2           분노의 질주: 라이드 오어 다이   2023-05-17  16,994,798,760
# 2       3                 슈퍼 마리오 브라더스   2023-04-26  15,203,394,429
# 3       4                       범죄도시3   2023-05-31  11,356,393,356
# 4       5  극장판 짱구는 못말려: 동물소환 닌자 배꼽수비대   2023-05-04   6,793,684,949
#
#   sales_percentage cumulative_sales   audience cumulative_audience  \
# 0            35.0%   41,558,564,678  3,936,452           3,936,452
# 1            14.3%   16,994,798,760  1,624,933           1,624,933
# 2            12.8%   22,924,703,237  1,559,739           2,328,838
# 3             9.6%   11,356,393,356  1,224,178           1,224,178
# 4             5.7%    6,831,105,825    685,661             688,746
#
#   screen_count show_count main_country country  \
# 0        1,819    139,717           미국      미국
# 1        1,731     82,524           미국      미국
# ...

# %%
df.to_csv("230506.csv", index=False)

# %%
df=pd.read_csv("KOBIS_월별박스오피스_230708.csv")
df3 = df.iloc[7:644].reset_index(drop=True)
df3.head()
# Out:
#   ■ 월별 박스오피스 Unnamed: 1  Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0          1  콘크리트 유토피아  2023-08-09  33,729,838,362      23.5%
# 1          2         밀수  2023-07-26  29,414,760,178      20.5%
# 2          3      오펜하이머  2023-08-15  26,923,397,740      18.8%
# 3          4       엘리멘탈  2023-06-14  12,526,218,715       8.7%
# 4          5      비공식작전  2023-08-02   9,760,586,384       6.8%
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0  33,754,618,362  3,452,681  3,454,857      1,731    110,766          한국
# 1  48,503,556,269  3,043,853  5,022,084      1,771    100,715          한국
# 2  26,923,397,740  2,525,885  2,525,885      1,636     79,345          미국
# 3  69,421,734,462  1,285,652  7,065,124      1,019     48,897          미국
# 4  10,170,842,196  1,013,010  1,056,202      1,151     44,657          한국
#
#   Unnamed: 11          Unnamed: 12
# 0          한국    롯데컬처웍스(주)롯데엔터테인먼트
# 1          한국  (주)넥스트엔터테인먼트월드(NEW)
# ...

# %%
df3.tail()
# Out:
#     ■ 월별 박스오피스               Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 632        619       에브리씽 에브리웨어 올 앳 원스+  2023-03-01          0       0.0%
# 633        619  신수원 감독전: 레인보우부터 오마주,13년         NaN          0       0.0%
# 634        619                     여자만세         NaN          0       0.0%
# 635        619     제24회 대구단편영화제 대구단편신작전         NaN          0       0.0%
# 636        619                       기담  2007-08-01          0       0.0%
#
#         Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 632              0          0          0          1          1          미국
# 633              0          0          0          1          1          한국
# 634              0          0          0          1          1          한국
# 635              0          0          0          1          1          한국
# 636  4,142,762,500          0    646,238          1          2          한국
#
#     Unnamed: 11        Unnamed: 12
# ...

# %%
df4 = df.iloc[649:-1].reset_index(drop=True)
df4.head()
# Out:
#   ■ 월별 박스오피스                Unnamed: 1  Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0          1                      엘리멘탈  2023-06-14  40,226,544,806      28.7%
# 1          2  미션 임파서블: 데드 레코닝 PART ONE  2023-07-12  36,264,590,140      25.9%
# 2          3                        밀수  2023-07-26  19,088,796,091      13.6%
# 3          4                     범죄도시3  2023-05-31   6,184,609,945       4.4%
# 4          5          인디아나 존스: 운명의 다이얼  2023-06-28   6,239,832,155       4.5%
#
#         Unnamed: 5 Unnamed: 6  Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0   56,895,515,747  4,086,918   5,779,472      1,664    124,676          미국
# 1   36,264,590,140  3,594,887   3,594,887      2,437    121,203          미국
# 2   19,088,796,091  1,978,231   1,978,231      1,932     54,142          한국
# 3  104,671,315,182    711,505  10,680,905        943     42,706          한국
# 4    8,501,034,347    618,807     860,174      1,268     34,242          미국
#
# ...

# %%
df4.tail()
# Out:
#     ■ 월별 박스오피스         Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 524        514                 애월  2019-09-26          0       0.0%
# 525        514         그 섬에 가고 싶다  1993-12-24          0       0.0%
# 526        514                 축제  1996-06-06          0       0.0%
# 527        514             학생부군신위  1996-03-01          0       0.0%
# 528        514  [뮤직&댄스 온 스크린] 댄스2         NaN          0       0.0%
#
#      Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 524  11,763,360          0      1,406          1          1          한국
# 525     221,000          0         43          1          1          한국
# 526     217,000          0         30          1          1          한국
# 527           0          0          0          1          1          한국
# 528           0          0          0          1          1          한국
#
#     Unnamed: 11    Unnamed: 12
# 524          한국  (주)드림팩트엔터테인먼트
# 525          한국            NaN
# ...

# %%
df3["month"]="23.08"
df4["month"]="23.07"

# %%
df3.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df3.head()
# Out:
#   ranking movie_name release_date           sales sales_percentage  \
# 0       1  콘크리트 유토피아   2023-08-09  33,729,838,362            23.5%
# 1       2         밀수   2023-07-26  29,414,760,178            20.5%
# 2       3      오펜하이머   2023-08-15  26,923,397,740            18.8%
# 3       4       엘리멘탈   2023-06-14  12,526,218,715             8.7%
# 4       5      비공식작전   2023-08-02   9,760,586,384             6.8%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0   33,754,618,362  3,452,681           3,454,857        1,731    110,766
# 1   48,503,556,269  3,043,853           5,022,084        1,771    100,715
# 2   26,923,397,740  2,525,885           2,525,885        1,636     79,345
# 3   69,421,734,462  1,285,652           7,065,124        1,019     48,897
# 4   10,170,842,196  1,013,010           1,056,202        1,151     44,657
#
#   main_country country          distributor  month
# 0           한국      한국    롯데컬처웍스(주)롯데엔터테인먼트  23.08
# ...

# %%
df4.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df4.head()
# Out:
#   ranking                movie_name release_date           sales  \
# 0       1                      엘리멘탈   2023-06-14  40,226,544,806
# 1       2  미션 임파서블: 데드 레코닝 PART ONE   2023-07-12  36,264,590,140
# 2       3                        밀수   2023-07-26  19,088,796,091
# 3       4                     범죄도시3   2023-05-31   6,184,609,945
# 4       5          인디아나 존스: 운명의 다이얼   2023-06-28   6,239,832,155
#
#   sales_percentage cumulative_sales   audience cumulative_audience  \
# 0            28.7%   56,895,515,747  4,086,918           5,779,472
# 1            25.9%   36,264,590,140  3,594,887           3,594,887
# 2            13.6%   19,088,796,091  1,978,231           1,978,231
# 3             4.4%  104,671,315,182    711,505          10,680,905
# 4             4.5%    8,501,034,347    618,807             860,174
#
#   screen_count show_count main_country country  \
# 0        1,664    124,676           미국      미국
# 1        2,437    121,203           미국      미국
# ...

# %%
df = pd.concat([df4, df3])
df.head()
# Out:
#   ranking                movie_name release_date           sales  \
# 0       1                      엘리멘탈   2023-06-14  40,226,544,806
# 1       2  미션 임파서블: 데드 레코닝 PART ONE   2023-07-12  36,264,590,140
# 2       3                        밀수   2023-07-26  19,088,796,091
# 3       4                     범죄도시3   2023-05-31   6,184,609,945
# 4       5          인디아나 존스: 운명의 다이얼   2023-06-28   6,239,832,155
#
#   sales_percentage cumulative_sales   audience cumulative_audience  \
# 0            28.7%   56,895,515,747  4,086,918           5,779,472
# 1            25.9%   36,264,590,140  3,594,887           3,594,887
# 2            13.6%   19,088,796,091  1,978,231           1,978,231
# 3             4.4%  104,671,315,182    711,505          10,680,905
# 4             4.5%    8,501,034,347    618,807             860,174
#
#   screen_count show_count main_country country  \
# 0        1,664    124,676           미국      미국
# 1        2,437    121,203           미국      미국
# ...

# %%
df.tail()
# Out:
#     ranking               movie_name release_date sales sales_percentage  \
# 632     619       에브리씽 에브리웨어 올 앳 원스+   2023-03-01     0             0.0%
# 633     619  신수원 감독전: 레인보우부터 오마주,13년          NaN     0             0.0%
# 634     619                     여자만세          NaN     0             0.0%
# 635     619     제24회 대구단편영화제 대구단편신작전          NaN     0             0.0%
# 636     619                       기담   2007-08-01     0             0.0%
#
#     cumulative_sales audience cumulative_audience screen_count show_count  \
# 632                0        0                   0            1          1
# 633                0        0                   0            1          1
# 634                0        0                   0            1          1
# 635                0        0                   0            1          1
# 636    4,142,762,500        0             646,238            1          2
#
#     main_country country        distributor  month
# ...

# %%
df.to_csv("230708.csv", index=False)

# %%
df=pd.read_csv("KOBIS_월별박스오피스_230910.csv")
df5 = df.iloc[7:709].reset_index(drop=True)
df5.head()
# Out:
#   ■ 월별 박스오피스          Unnamed: 1  Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0          1                 30일  2023-10-03  18,306,995,855      27.2%
# 1          2      그대들은 어떻게 살 것인가  2023-10-25  10,325,060,680      15.3%
# 2          3  천박사 퇴마 연구소: 설경의 비밀  2023-09-27   9,567,420,683      14.2%
# 3          4            1947 보스톤  2023-09-27   4,805,311,432       7.1%
# 4          5               크리에이터  2023-10-03   2,701,136,233       4.0%
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0  18,484,046,620  1,861,665  1,880,121      1,226    104,434          한국
# 1  10,325,060,680  1,063,664  1,063,664      1,733     47,081          일본
# 2  18,616,278,692    969,779  1,914,020      1,511     69,757          한국
# 3   9,207,227,580    529,880    991,277      1,282     41,639          한국
# 4   2,765,702,233    255,753    261,773        878     25,103          미국
#
#   Unnamed: 11                                 Unnamed: 12
# ...

# %%
df5.tail()
# Out:
#     ■ 월별 박스오피스                   Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 697        694  제9회 서울국제음식영화제 오감만족 국제단편경선 4         NaN          0       0.0%
# 698        694                       시네마 퓨처         NaN          0       0.0%
# 699        694                        니나 내나  2019-10-30          0       0.0%
# 700        694                   이소정 감독 단편선         NaN          0       0.0%
# 701        694                     오늘 출가합니다  2023-04-05          0       0.0%
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 697          0          0          0          1          1          기타
# 698          0          0          0          1          1       오스트리아
# 699          0          0          0          1          1          한국
# 700          0          0          0          1          1          한국
# 701          0          0          0          1          1          한국
#
#     Unnamed: 11 Unnamed: 12
# 697          기타         NaN
# ...

# %%
df6 = df.iloc[714:-1].reset_index(drop=True)
df6.head()
# Out:
#   ■ 월별 박스오피스          Unnamed: 1  Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0          1                   잠  2023-09-06  13,379,208,421      20.5%
# 1          2  천박사 퇴마 연구소: 설경의 비밀  2023-09-27   9,048,858,009      13.9%
# 2          3               오펜하이머  2023-08-15   7,124,568,890      10.9%
# 3          4            1947 보스톤  2023-09-27   4,401,916,148       6.7%
# 4          5         달짝지근해: 7510  2023-08-15   3,920,187,519       6.0%
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0  13,455,612,321  1,409,809  1,417,547      1,231     99,675          한국
# 1   9,048,858,009    944,241    944,241      1,502     28,843          한국
# 2  34,047,966,630    676,425  3,202,310      1,158     50,884          미국
# 3   4,401,916,148    461,397    461,397      1,273     20,165          한국
# 4  13,397,099,955    407,480  1,381,850        937     39,989          한국
#
#   Unnamed: 11                                 Unnamed: 12
# ...

# %%
df6.tail()
# Out:
#     ■ 월별 박스오피스                       Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 770        747             운하의 다섯 스토리와 한 세기의 인생        NaN          0
# 771        747                          엘리스 & 톰        NaN          0
# 772        747                          길거리 환전소        NaN          0
# 773        747                         그 가족의 비밀        NaN          0
# 774        747  제15회 서울영등포국제초단편영화제 글로벌 문화예술교육 2        NaN          0
#
#     Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 770       0.0%          0          0          0          1          2
# 771       0.0%          0          0          0          1          2
# 772       0.0%          0          0          0          1          2
# 773       0.0%          0          0          0          1          2
# 774       0.0%          0          0          0          1          1
#
#     Unnamed: 10 Unnamed: 11 Unnamed: 12
# 770          기타          기타         NaN
# 771         브라질         브라질         NaN
# ...

# %%
df5["month"]="23.10"
df6["month"]="23.09"

# %%
df5.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df5.head()
# Out:
#   ranking          movie_name release_date           sales sales_percentage  \
# 0       1                 30일   2023-10-03  18,306,995,855            27.2%
# 1       2      그대들은 어떻게 살 것인가   2023-10-25  10,325,060,680            15.3%
# 2       3  천박사 퇴마 연구소: 설경의 비밀   2023-09-27   9,567,420,683            14.2%
# 3       4            1947 보스톤   2023-09-27   4,805,311,432             7.1%
# 4       5               크리에이터   2023-10-03   2,701,136,233             4.0%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0   18,484,046,620  1,861,665           1,880,121        1,226    104,434
# 1   10,325,060,680  1,063,664           1,063,664        1,733     47,081
# 2   18,616,278,692    969,779           1,914,020        1,511     69,757
# 3    9,207,227,580    529,880             991,277        1,282     41,639
# 4    2,765,702,233    255,753             261,773          878     25,103
#
# ...

# %%
df6.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df6.head()
# Out:
#   ranking          movie_name release_date           sales sales_percentage  \
# 0       1                   잠   2023-09-06  13,379,208,421            20.5%
# 1       2  천박사 퇴마 연구소: 설경의 비밀   2023-09-27   9,048,858,009            13.9%
# 2       3               오펜하이머   2023-08-15   7,124,568,890            10.9%
# 3       4            1947 보스톤   2023-09-27   4,401,916,148             6.7%
# 4       5         달짝지근해: 7510   2023-08-15   3,920,187,519             6.0%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0   13,455,612,321  1,409,809           1,417,547        1,231     99,675
# 1    9,048,858,009    944,241             944,241        1,502     28,843
# 2   34,047,966,630    676,425           3,202,310        1,158     50,884
# 3    4,401,916,148    461,397             461,397        1,273     20,165
# 4   13,397,099,955    407,480           1,381,850          937     39,989
#
# ...

# %%
df = pd.concat([df6, df5])
df.head()
# Out:
#   ranking          movie_name release_date           sales sales_percentage  \
# 0       1                   잠   2023-09-06  13,379,208,421            20.5%
# 1       2  천박사 퇴마 연구소: 설경의 비밀   2023-09-27   9,048,858,009            13.9%
# 2       3               오펜하이머   2023-08-15   7,124,568,890            10.9%
# 3       4            1947 보스톤   2023-09-27   4,401,916,148             6.7%
# 4       5         달짝지근해: 7510   2023-08-15   3,920,187,519             6.0%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0   13,455,612,321  1,409,809           1,417,547        1,231     99,675
# 1    9,048,858,009    944,241             944,241        1,502     28,843
# 2   34,047,966,630    676,425           3,202,310        1,158     50,884
# 3    4,401,916,148    461,397             461,397        1,273     20,165
# 4   13,397,099,955    407,480           1,381,850          937     39,989
#
# ...

# %%
df.to_csv("230910.csv", index=False)

# %%
df=pd.read_csv("KOBIS_월별박스오피스_231112.csv")

# %%
df7 = df.iloc[7:687].reset_index(drop=True)
df7.head()
# Out:
#   ■ 월별 박스오피스                            Unnamed: 1  Unnamed: 2  \
# 0          1                                 서울의 봄  2023-11-22
# 1          2                            노량: 죽음의 바다  2023-12-20
# 2          3                          아쿠아맨과 로스트 킹덤  2023-12-20
# 3          4  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~  2023-12-22
# 4          5                                3일의 휴가  2023-12-06
#
#        Unnamed: 3 Unnamed: 4       Unnamed: 5 Unnamed: 6  Unnamed: 7  \
# 0  87,680,455,951      53.4%  115,350,491,410  8,901,879  11,854,779
# 1  34,032,608,940      20.7%   34,032,608,940  3,438,133   3,438,133
# 2   7,459,599,772       4.5%    7,459,599,772    722,986     722,986
# 3   5,506,327,689       3.4%    5,506,327,689    568,269     568,269
# 4   4,808,376,689       2.9%    4,835,070,689    511,659     514,541
#
#   Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0      2,463    215,008          한국          한국
# 1      2,196     81,643          한국          한국
# ...

# %%
df7.tail()
# Out:
#     ■ 월별 박스오피스                       Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 675        662                              황진이  1986-09-18          0
# 676        662                        미워도 다시 한번  1968-07-16          0
# 677        662                               만추  1982-02-28          0
# 678        662                   태양의 서커스 월드 어웨이  2016-01-06          0
# 679        662  My Shooting Star - 이한주 배우전 단편전2         NaN          0
#
#     Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 675       0.0%          0          0          0          1          2
# 676       0.0%          0          0          0          1          2
# 677       0.0%          0          0          0          1          2
# 678       0.0%          0          0          0          1          1
# 679       0.0%          0          0          0          1          1
#
#     Unnamed: 10 Unnamed: 11   Unnamed: 12
# 675          한국          한국           NaN
# ...

# %%
df8 = df.iloc[692:-1].reset_index(drop=True)
df8.head()
# Out:
#   ■ 월별 박스오피스      Unnamed: 1  Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0          1           서울의 봄  2023-11-22  27,670,035,459      37.8%
# 1          2  그대들은 어떻게 살 것인가  2023-10-25   8,858,746,363      12.1%
# 2          3           더 마블스  2023-11-08   6,807,601,786       9.3%
# 3          4       프레디의 피자가게  2023-11-15   5,706,230,228       7.8%
# 4          5             소년들  2023-11-01   4,297,375,469       5.9%
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0  27,670,035,459  2,952,900  2,952,900      2,328     77,291          한국
# 1  19,183,807,043    903,085  1,966,749      1,343     69,594          일본
# 2   6,807,601,786    686,976    686,976      1,532     66,622          미국
# 3   5,706,230,228    587,136    587,136      1,041     28,886          미국
# 4   4,464,069,469    452,168    470,735      1,042     43,210          한국
#
#   Unnamed: 11            Unnamed: 12
# 0          한국  메가박스중앙(주) 플러스엠 엔터테인먼트
# ...

# %%
df8.tail()
# Out:
#     ■ 월별 박스오피스       Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 806        770        21번가의 살인자         NaN          0       0.0%
# 807        770       찬실이는 복도 많지  2020-03-05          0       0.0%
# 808        770         서바이벌 택틱스  2024-02-21          0       0.0%
# 809        770           씨앗의 시간  2024-11-20          0       0.0%
# 810        770  2030 청년영화 2회 GV         NaN          0       0.0%
#
#       Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 806    1,267,000          0        241          1          1         프랑스
# 807  255,235,830          0     29,900          1          1          한국
# 808      559,000          0         70          1          1          한국
# 809      449,000          0         64          1          1          한국
# 810            0          0          0          1          1          한국
#
#     Unnamed: 11 Unnamed: 12
# 806         프랑스         NaN
# 807          한국          찬란
# 808          한국        필름다빈
# ...

# %%
df7["month"]="23.12"
df8["month"]="23.11"

# %%
df7.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df7.head()
# Out:
#   ranking                            movie_name release_date           sales  \
# 0       1                                 서울의 봄   2023-11-22  87,680,455,951
# 1       2                            노량: 죽음의 바다   2023-12-20  34,032,608,940
# 2       3                          아쿠아맨과 로스트 킹덤   2023-12-20   7,459,599,772
# 3       4  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~   2023-12-22   5,506,327,689
# 4       5                                3일의 휴가   2023-12-06   4,808,376,689
#
#   sales_percentage cumulative_sales   audience cumulative_audience  \
# 0            53.4%  115,350,491,410  8,901,879          11,854,779
# 1            20.7%   34,032,608,940  3,438,133           3,438,133
# 2             4.5%    7,459,599,772    722,986             722,986
# 3             3.4%    5,506,327,689    568,269             568,269
# 4             2.9%    4,835,070,689    511,659             514,541
#
#   screen_count show_count main_country country  \
# 0        2,463    215,008           한국      한국
# ...

# %%
df8.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df8.head()
# Out:
#   ranking      movie_name release_date           sales sales_percentage  \
# 0       1           서울의 봄   2023-11-22  27,670,035,459            37.8%
# 1       2  그대들은 어떻게 살 것인가   2023-10-25   8,858,746,363            12.1%
# 2       3           더 마블스   2023-11-08   6,807,601,786             9.3%
# 3       4       프레디의 피자가게   2023-11-15   5,706,230,228             7.8%
# 4       5             소년들   2023-11-01   4,297,375,469             5.9%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0   27,670,035,459  2,952,900           2,952,900        2,328     77,291
# 1   19,183,807,043    903,085           1,966,749        1,343     69,594
# 2    6,807,601,786    686,976             686,976        1,532     66,622
# 3    5,706,230,228    587,136             587,136        1,041     28,886
# 4    4,464,069,469    452,168             470,735        1,042     43,210
#
#   main_country country            distributor  month
# ...

# %%
df = pd.concat([df8, df7])
df.head()
# Out:
#   ranking      movie_name release_date           sales sales_percentage  \
# 0       1           서울의 봄   2023-11-22  27,670,035,459            37.8%
# 1       2  그대들은 어떻게 살 것인가   2023-10-25   8,858,746,363            12.1%
# 2       3           더 마블스   2023-11-08   6,807,601,786             9.3%
# 3       4       프레디의 피자가게   2023-11-15   5,706,230,228             7.8%
# 4       5             소년들   2023-11-01   4,297,375,469             5.9%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0   27,670,035,459  2,952,900           2,952,900        2,328     77,291
# 1   19,183,807,043    903,085           1,966,749        1,343     69,594
# 2    6,807,601,786    686,976             686,976        1,532     66,622
# 3    5,706,230,228    587,136             587,136        1,041     28,886
# 4    4,464,069,469    452,168             470,735        1,042     43,210
#
#   main_country country            distributor  month
# ...

# %%
df.to_csv("231112.csv", index=False)

# %%
df=pd.read_csv("KOBIS_월별박스오피스_240102.csv")

# %%
df9 = df.iloc[7:446].reset_index(drop=True)
df9.head()
# Out:
#   ■ 월별 박스오피스                      Unnamed: 1  Unnamed: 2      Unnamed: 3  \
# 0          1                              파묘  2024-02-22  35,074,653,666
# 1          2                              웡카  2024-01-31  28,559,191,141
# 2          3                            시민덕희  2024-01-24   9,958,903,001
# 3          4                            건국전쟁  2024-02-01   9,619,732,158
# 4          5  귀멸의 칼날: 인연의 기적, 그리고 합동 강화 훈련으로  2024-02-14   4,901,269,600
#
#   Unnamed: 4      Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0      31.7%  35,074,653,666  3,697,234  3,697,234      2,355     66,290
# 1      25.8%  30,068,563,086  2,943,396  3,124,697      1,753    124,701
# 2       9.0%  16,075,976,297  1,038,452  1,700,935      1,281     58,090
# 3       8.7%   9,637,314,158  1,031,011  1,032,762        956     40,252
# 4       4.4%   4,901,269,600    426,871    426,871        393     20,640
#
#   Unnamed: 10 Unnamed: 11          Unnamed: 12
# ...

# %%
df9.tail()
# Out:
#     ■ 월별 박스오피스 Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 434        434         영웅  2022-12-21          0       0.0%          0
# 435        434   마이 제너레이션  2004-12-03          0       0.0%          0
# 436        434       바이 준  1998-03-28          0       0.0%          0
# 437        434   고양이를 부탁해  2001-10-12          0       0.0%          0
# 438        434      나쁜 영화  1997-08-02          0       0.0%          0
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 434          0          0          1          1          한국          한국
# 435          0          0          1          2          한국          한국
# 436          0          0          1          2          한국          한국
# 437          0          0          1          2          한국          한국
# 438          0          0          1          2          한국          한국
#
#             Unnamed: 12
# 434           (주)씨제이이엔엠
# 435        아트플러스시네마네트워크
# 436                 NaN
# ...

# %%
df10 = df.iloc[451:-1].reset_index(drop=True)
df10.head()
# Out:
#   ■ 월별 박스오피스  Unnamed: 1  Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0          1          위시  2024-01-03  12,946,267,193      17.3%
# 1          2     외계+인 2부  2024-01-10  13,016,779,919      17.4%
# 2          3       서울의 봄  2023-11-22  11,970,794,644      16.0%
# 3          4  노량: 죽음의 바다  2023-12-20  10,854,904,560      14.5%
# 4          5        시민덕희  2024-01-24   6,117,073,296       8.2%
#
#         Unnamed: 5 Unnamed: 6  Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0   12,956,605,193  1,356,390   1,357,472      1,421     83,743          미국
# 1   13,016,779,919  1,349,620   1,349,620      1,390     89,503          한국
# 2  127,321,286,054  1,206,194  13,060,973      1,614     75,922          한국
# 3   44,887,513,500  1,122,234   4,560,367      1,706     72,225          한국
# 4    6,117,073,296    662,483     662,483      1,272     37,916          한국
#
#   Unnamed: 11                      Unnamed: 12
# 0          미국               월트디즈니컴퍼니코리아 유한책임회사
# ...

# %%
df10.tail()
# Out:
#     ■ 월별 박스오피스          Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 484        483                 파이란  2001-04-28          0       0.0%
# 485        483              해야 할 일  2024-09-25          0       0.0%
# 486        483  레전더리 콘서트: 레너드 번스타인  2021-01-03          0       0.0%
# 487        483                   탑  2022-11-03          0       0.0%
# 488        483            번지점프를 하다  2001-02-02          0       0.0%
#
#      Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 484  13,402,270          0      1,380          1          2          한국
# 485   4,020,000          0        510          1          1          한국
# 486  13,413,500          0        519          1          1          독일
# 487  57,559,293          0      6,134          1          1          한국
# 488  58,648,800          0      7,248          1          2          한국
#
#     Unnamed: 11                               Unnamed: 12
# 484          한국                      (주)영화사오원,(주)튜브엔터테인먼트
# ...

# %%
df9["month"]="24.02"
df10["month"]="24.01"

# %%
df9.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df9.head()
# Out:
#   ranking                      movie_name release_date           sales  \
# 0       1                              파묘   2024-02-22  35,074,653,666
# 1       2                              웡카   2024-01-31  28,559,191,141
# 2       3                            시민덕희   2024-01-24   9,958,903,001
# 3       4                            건국전쟁   2024-02-01   9,619,732,158
# 4       5  귀멸의 칼날: 인연의 기적, 그리고 합동 강화 훈련으로   2024-02-14   4,901,269,600
#
#   sales_percentage cumulative_sales   audience cumulative_audience  \
# 0            31.7%   35,074,653,666  3,697,234           3,697,234
# 1            25.8%   30,068,563,086  2,943,396           3,124,697
# 2             9.0%   16,075,976,297  1,038,452           1,700,935
# 3             8.7%    9,637,314,158  1,031,011           1,032,762
# 4             4.4%    4,901,269,600    426,871             426,871
#
#   screen_count show_count main_country country          distributor  month
# ...

# %%
df10.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df10.head()
# Out:
#   ranking  movie_name release_date           sales sales_percentage  \
# 0       1          위시   2024-01-03  12,946,267,193            17.3%
# 1       2     외계+인 2부   2024-01-10  13,016,779,919            17.4%
# 2       3       서울의 봄   2023-11-22  11,970,794,644            16.0%
# 3       4  노량: 죽음의 바다   2023-12-20  10,854,904,560            14.5%
# 4       5        시민덕희   2024-01-24   6,117,073,296             8.2%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0   12,956,605,193  1,356,390           1,357,472        1,421     83,743
# 1   13,016,779,919  1,349,620           1,349,620        1,390     89,503
# 2  127,321,286,054  1,206,194          13,060,973        1,614     75,922
# 3   44,887,513,500  1,122,234           4,560,367        1,706     72,225
# 4    6,117,073,296    662,483             662,483        1,272     37,916
#
#   main_country country                      distributor  month
# ...

# %%
df = pd.concat([df10, df9])

# %%
df.to_csv("240102.csv", index=False)

# %%
df=pd.read_csv("KOBIS_월별박스오피스_240304.csv")

# %%
df11 = df.iloc[7:542].reset_index(drop=True)
df11.head()
# Out:
#   ■ 월별 박스오피스 Unnamed: 1  Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0          1      범죄도시4  2024-04-24  47,568,478,254      52.9%
# 1          2      쿵푸팬더4  2024-04-10  13,113,276,904      14.6%
# 2          3         파묘  2024-02-22   8,837,982,638       9.8%
# 3          4       댓글부대  2024-03-27   4,185,464,098       4.7%
# 4          5  남은 인생 10년  2023-05-24   2,862,042,165       3.2%
#
#         Unnamed: 5 Unnamed: 6  Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0   47,568,478,254  5,005,372   5,005,372      2,980    112,858          한국
# 1   13,124,943,904  1,403,363   1,404,570      2,311     90,797          미국
# 2  114,631,306,846    902,841  11,860,132      1,280     76,395          한국
# 3    9,227,726,211    430,033     971,080      1,059     43,303          한국
# 4    2,862,042,165    287,554     287,554        529     18,821          일본
#
#   Unnamed: 11                            Unnamed: 12
# 0          한국  주식회사 에이비오엔터테인먼트,메가박스중앙(주) 플러스엠 엔터테인먼트
# ...

# %%
df11.tail()
# Out:
#     ■ 월별 박스오피스  Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 530        526       비공식작전  2023-08-02          0       0.0%          0
# 531        526  그녀를 믿지 마세요  2004-02-20          0       0.0%          0
# 532        526     범죄의 재구성  2004-04-15          0       0.0%          0
# 533        526          타짜  2006-09-28          0       0.0%          0
# 534        526  찬실이는 복도 많지  2020-03-05          0       0.0%          0
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 530          0          0          1          1          한국          한국
# 531          0          0          1          2          한국          한국
# 532          0          0          1          2          한국          한국
# 533          0          0          1          2          한국          한국
# 534          0          0          1          1          한국          한국
#
#     Unnamed: 12
# 530      (주)쇼박스
# 531   (주)시네마서비스
# 532      (주)쇼박스
# 533   씨제이엔터테인먼트
# ...

# %%
df12 = df.iloc[547:-1].reset_index(drop=True)
df12.head()
# Out:
#   ■ 월별 박스오피스       Unnamed: 1  Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0          1               파묘  2024-02-22  70,718,670,542      60.7%
# 1          2           듄: 파트2  2024-02-28  19,142,164,349      16.4%
# 2          3             댓글부대  2024-03-27   5,042,262,113       4.3%
# 3          4               웡카  2024-01-31   3,838,072,524       3.3%
# 4          5  고질라 X 콩: 뉴 엠파이어  2024-03-27   3,221,961,514       2.8%
#
#         Unnamed: 5 Unnamed: 6  Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0  105,793,324,208  7,260,057  10,957,291      2,367    218,130          한국
# 1   21,941,132,462  1,617,518   1,886,023      1,190     65,973          미국
# 2    5,042,262,113    541,047     541,047      1,228     24,274          한국
# 3   33,906,635,610    401,512   3,526,209        695     19,507          미국
# 4    3,221,961,514    321,128     321,128        995     16,323          미국
#
#   Unnamed: 11    Unnamed: 12
# 0          한국         (주)쇼박스
# 1          미국  워너브러더스 코리아(주)
# ...

# %%
df11["month"]="24.04"
df12["month"]="24.03"

# %%
df11.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df11.head()
# Out:
#   ranking movie_name release_date           sales sales_percentage  \
# 0       1      범죄도시4   2024-04-24  47,568,478,254            52.9%
# 1       2      쿵푸팬더4   2024-04-10  13,113,276,904            14.6%
# 2       3         파묘   2024-02-22   8,837,982,638             9.8%
# 3       4       댓글부대   2024-03-27   4,185,464,098             4.7%
# 4       5  남은 인생 10년   2023-05-24   2,862,042,165             3.2%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0   47,568,478,254  5,005,372           5,005,372        2,980    112,858
# 1   13,124,943,904  1,403,363           1,404,570        2,311     90,797
# 2  114,631,306,846    902,841          11,860,132        1,280     76,395
# 3    9,227,726,211    430,033             971,080        1,059     43,303
# 4    2,862,042,165    287,554             287,554          529     18,821
#
#   main_country country                            distributor  month
# ...

# %%
df12.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df12.head()
# Out:
#   ranking       movie_name release_date           sales sales_percentage  \
# 0       1               파묘   2024-02-22  70,718,670,542            60.7%
# 1       2           듄: 파트2   2024-02-28  19,142,164,349            16.4%
# 2       3             댓글부대   2024-03-27   5,042,262,113             4.3%
# 3       4               웡카   2024-01-31   3,838,072,524             3.3%
# 4       5  고질라 X 콩: 뉴 엠파이어   2024-03-27   3,221,961,514             2.8%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0  105,793,324,208  7,260,057          10,957,291        2,367    218,130
# 1   21,941,132,462  1,617,518           1,886,023        1,190     65,973
# 2    5,042,262,113    541,047             541,047        1,228     24,274
# 3   33,906,635,610    401,512           3,526,209          695     19,507
# 4    3,221,961,514    321,128             321,128          995     16,323
#
#   main_country country    distributor  month
# ...

# %%
df = pd.concat([df12, df11])

# %%
df.to_csv("240304.csv", index=False)

# %%
df=pd.read_csv("KOBIS_월별박스오피스_240506.csv")

# %%
df13 = df.iloc[7:649].reset_index(drop=True)
df13.head()
# Out:
#   ■ 월별 박스오피스     Unnamed: 1  Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0          1      인사이드 아웃 2  2024-06-12  54,296,410,494      49.9%
# 1          2           하이재킹  2024-06-21  10,314,943,018       9.5%
# 2          3  퓨리오사: 매드맥스 사가  2024-05-22   7,986,194,948       7.3%
# 3          4           원더랜드  2024-06-05   5,857,952,571       5.4%
# 4          5          핸섬가이즈  2024-06-26   4,224,677,026       3.9%
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0  54,296,410,494  5,638,833  5,638,833      2,619    191,541          미국
# 1  10,316,869,018  1,087,330  1,087,544      1,155     41,879          한국
# 2  16,420,562,828    786,121  1,598,473      1,360     48,082          미국
# 3   5,898,947,571    618,867    623,338      1,165     43,764          한국
# 4   4,226,900,026    458,626    458,873        965     18,195          한국
#
#   Unnamed: 11                          Unnamed: 12
# 0          미국                   월트디즈니컴퍼니코리아 유한책임회사
# ...

# %%
df13.tail()
# Out:
#     ■ 월별 박스오피스       Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 637        627      임신한 나무와 도깨비  2022-01-27          0       0.0%          0
# 638        627  세계의 이미지와 전쟁의 각인         NaN          0       0.0%          0
# 639        627               짝코  1983-10-23          0       0.0%          0
# 640        627               송환  2004-03-19          0       0.0%          0
# 641        627        땡큐 포 더 레인         NaN          0       0.0%          0
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 637          0          0          1          1          한국          한국
# 638          0          0          1          1          독일          독일
# 639          0          0          1          2          한국          한국
# 640          0          0          1          2          한국          한국
# 641          0          0          1          1          케냐          케냐
#
#     Unnamed: 12
# 637     (주)시네마달
# 638         NaN
# 639         NaN
# ...

# %%
df14 = df.iloc[654:-1].reset_index(drop=True)
df14.head()
# Out:
#   ■ 월별 박스오피스          Unnamed: 1  Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0          1               범죄도시4  2024-04-24  59,331,646,657      54.1%
# 1          2        혹성탈출: 새로운 시대  2024-05-08   8,983,534,876       8.2%
# 2          3             그녀가 죽었다  2024-05-15   7,991,507,015       7.3%
# 3          4       퓨리오사: 매드맥스 사가  2024-05-22   8,434,367,880       7.7%
# 4          5  극장판 하이큐!! 쓰레기장의 결전  2024-05-15   5,529,154,607       5.0%
#
#         Unnamed: 5 Unnamed: 6  Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0  106,900,124,911  6,174,857  11,180,229      2,795    237,235          한국
# 1    8,983,534,876    887,475     887,475      1,184     51,514          미국
# 2    7,995,476,015    837,143     837,584      1,008     48,245          한국
# 3    8,434,367,880    812,352     812,352      1,442     44,871          미국
# 4    5,529,154,607    536,130     536,130      1,212     32,913          일본
#
#   Unnamed: 11                              Unnamed: 12
# ...

# %%
df14.tail()
# Out:
#     ■ 월별 박스오피스       Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 573        557      성냥팔이 소녀의 재림  2002-09-12          0       0.0%          0
# 574        557           파산의 기술         NaN          0       0.0%    504,000
# 575        557              만다라  1981-09-12          0       0.0%  2,568,000
# 576        557  달마가 동쪽으로 간 까닭은?  1989-09-29          0       0.0%          0
# 577        557             마카리오         NaN          0       0.0%          0
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 573          0          0          1          2          한국          한국
# 574          0         74          1          1          한국          한국
# 575          0        934          1          2          한국          한국
# 576          0          0          1          2          한국          한국
# 577          0          0        NaN          1         멕시코         멕시코
#
#     Unnamed: 12
# 573   씨제이엔터테인먼트
# 574         NaN
# 575         NaN
# ...

# %%
df13["month"]="24.06"
df14["month"]="24.05"

# %%
df13.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df13.head()
# Out:
#   ranking     movie_name release_date           sales sales_percentage  \
# 0       1      인사이드 아웃 2   2024-06-12  54,296,410,494            49.9%
# 1       2           하이재킹   2024-06-21  10,314,943,018             9.5%
# 2       3  퓨리오사: 매드맥스 사가   2024-05-22   7,986,194,948             7.3%
# 3       4           원더랜드   2024-06-05   5,857,952,571             5.4%
# 4       5          핸섬가이즈   2024-06-26   4,224,677,026             3.9%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0   54,296,410,494  5,638,833           5,638,833        2,619    191,541
# 1   10,316,869,018  1,087,330           1,087,544        1,155     41,879
# 2   16,420,562,828    786,121           1,598,473        1,360     48,082
# 3    5,898,947,571    618,867             623,338        1,165     43,764
# 4    4,226,900,026    458,626             458,873          965     18,195
#
#   main_country country                          distributor  month
# ...

# %%
df14.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df14.head()
# Out:
#   ranking          movie_name release_date           sales sales_percentage  \
# 0       1               범죄도시4   2024-04-24  59,331,646,657            54.1%
# 1       2        혹성탈출: 새로운 시대   2024-05-08   8,983,534,876             8.2%
# 2       3             그녀가 죽었다   2024-05-15   7,991,507,015             7.3%
# 3       4       퓨리오사: 매드맥스 사가   2024-05-22   8,434,367,880             7.7%
# 4       5  극장판 하이큐!! 쓰레기장의 결전   2024-05-15   5,529,154,607             5.0%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0  106,900,124,911  6,174,857          11,180,229        2,795    237,235
# 1    8,983,534,876    887,475             887,475        1,184     51,514
# 2    7,995,476,015    837,143             837,584        1,008     48,245
# 3    8,434,367,880    812,352             812,352        1,442     44,871
# 4    5,529,154,607    536,130             536,130        1,212     32,913
#
# ...

# %%
df = pd.concat([df14, df13])

# %%
df.head()
df.to_csv("240506.csv", index=False)

# %%
import pandas as pd
import os
os.chdir(r"H:\&문체부 공모전&")

df=pd.read_csv("KOBIS_월별박스오피스_240708.csv")

# %%
df15 = df.iloc[7:752].reset_index(drop=True)
df15.head()
# Out:
#   ■ 월별 박스오피스  Unnamed: 1  Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0          1         파일럿  2024-07-31  37,622,232,042      32.2%
# 1          2  에이리언: 로물루스  2024-08-14  16,004,583,339      13.7%
# 2          3     사랑의 하츄핑  2024-08-07   7,549,787,272       6.5%
# 3          4      슈퍼배드 4  2024-07-24   6,397,596,976       5.5%
# 4          5      행복의 나라  2024-08-14   6,299,715,896       5.4%
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0  41,070,640,861  4,032,634  4,457,939      1,956    169,009          한국
# 1  16,004,583,339  1,560,130  1,560,130      1,436     66,005          미국
# 2   7,679,896,522    838,138    849,826      1,159     37,437          한국
# 3  14,083,082,100    704,730  1,548,560      1,110     35,852          미국
# 4   6,302,599,896    681,438    681,731      1,096     42,676          한국
#
#   Unnamed: 11          Unnamed: 12
# 0          한국    롯데컬처웍스(주)롯데엔터테인먼트
# 1          미국   월트디즈니컴퍼니코리아 유한책임회사
# ...

# %%
df15.tail()
# Out:
#     ■ 월별 박스오피스   Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 740        730  AM I FUNNY?         NaN          0       0.0%          0
# 741        730    사랑은 고양이처럼         NaN          0       0.0%          0
# 742        730     지금, 오아시스         NaN          0       0.0%          0
# 743        730   솔리드 바이 더 씨         NaN          0       0.0%          0
# 744        730       두 개의 문  2012-06-21          0       0.0%          0
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10     Unnamed: 11  \
# 740          0          0          1          2          기타              기타
# 741          0          0          1          1          한국           한국,태국
# 742          0          0          1          1       말레이시아  말레이시아,싱가포르,프랑스
# 743          0          0          1          1          태국              태국
# 744          0          0          1          2          한국              한국
#
#     Unnamed: 12
# 740         NaN
# 741         NaN
# 742         NaN
# ...

# %%
df16 = df.iloc[757:-1].reset_index(drop=True)
df16.head()
# Out:
#   ■ 월별 박스오피스 Unnamed: 1  Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0          1  인사이드 아웃 2  2024-06-12  26,472,253,172      23.0%
# 1          2         탈주  2024-07-03  22,537,334,282      19.5%
# 2          3   데드풀과 울버린  2024-07-24  13,839,704,940      12.0%
# 3          4      핸섬가이즈  2024-06-26  12,116,866,192      10.5%
# 4          5     슈퍼배드 4  2024-07-24   7,685,485,124       6.7%
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0  80,768,663,666  2,767,299  8,406,132      1,664    120,555          미국
# 1  22,665,054,282  2,382,788  2,396,691      1,234    108,501          한국
# 2  13,839,704,940  1,352,113  1,352,113      1,948     60,958          미국
# 3  16,343,766,218  1,289,849  1,748,722      1,065     73,126          한국
# 4   7,685,485,124    843,830    843,830      1,178     36,541          미국
#
#   Unnamed: 11            Unnamed: 12
# 0          미국     월트디즈니컴퍼니코리아 유한책임회사
# 1          한국  메가박스중앙(주) 플러스엠 엔터테인먼트
# ...

# %%
df16.tail()
# Out:
#     ■ 월별 박스오피스             Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 603        598  아리랑시네센터X이경미, 잘돼가?무엇이든         NaN          0       0.0%
# 604        598      필름다빈X아리랑인디웨이브 섹션1         NaN          0       0.0%
# 605        598     필름다빈X아리랑인디웨이브 섹션 2         NaN          0       0.0%
# 606        598                     하녀  1960-11-03          0       0.0%
# 607        608                    블리츠  2011-12-07     -6,000       0.0%
#
#      Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 603           0          0          0          1          1          한국
# 604           0          0          0          1          1          한국
# 605           0          0          0          1          1          한국
# 606  42,812,000          0     10,559          1          2          한국
# 607      -6,000         -3         -3        NaN          3          영국
#
#     Unnamed: 11 Unnamed: 12
# 603          한국         NaN
# 604          한국         NaN
# ...

# %%
df15["month"]="24.08"
df16["month"]="24.07"

# %%
df15.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df15.head()
# Out:
#   ranking  movie_name release_date           sales sales_percentage  \
# 0       1         파일럿   2024-07-31  37,622,232,042            32.2%
# 1       2  에이리언: 로물루스   2024-08-14  16,004,583,339            13.7%
# 2       3     사랑의 하츄핑   2024-08-07   7,549,787,272             6.5%
# 3       4      슈퍼배드 4   2024-07-24   6,397,596,976             5.5%
# 4       5      행복의 나라   2024-08-14   6,299,715,896             5.4%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0   41,070,640,861  4,032,634           4,457,939        1,956    169,009
# 1   16,004,583,339  1,560,130           1,560,130        1,436     66,005
# 2    7,679,896,522    838,138             849,826        1,159     37,437
# 3   14,083,082,100    704,730           1,548,560        1,110     35,852
# 4    6,302,599,896    681,438             681,731        1,096     42,676
#
#   main_country country          distributor  month
# 0           한국      한국    롯데컬처웍스(주)롯데엔터테인먼트  24.08
# ...

# %%
df16.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df16.head()
# Out:
#   ranking movie_name release_date           sales sales_percentage  \
# 0       1  인사이드 아웃 2   2024-06-12  26,472,253,172            23.0%
# 1       2         탈주   2024-07-03  22,537,334,282            19.5%
# 2       3   데드풀과 울버린   2024-07-24  13,839,704,940            12.0%
# 3       4      핸섬가이즈   2024-06-26  12,116,866,192            10.5%
# 4       5     슈퍼배드 4   2024-07-24   7,685,485,124             6.7%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0   80,768,663,666  2,767,299           8,406,132        1,664    120,555
# 1   22,665,054,282  2,382,788           2,396,691        1,234    108,501
# 2   13,839,704,940  1,352,113           1,352,113        1,948     60,958
# 3   16,343,766,218  1,289,849           1,748,722        1,065     73,126
# 4    7,685,485,124    843,830             843,830        1,178     36,541
#
#   main_country country            distributor  month
# 0           미국      미국     월트디즈니컴퍼니코리아 유한책임회사  24.07
# ...

# %%
df = pd.concat([df16, df15])
df.head()
# Out:
#   ranking movie_name release_date           sales sales_percentage  \
# 0       1  인사이드 아웃 2   2024-06-12  26,472,253,172            23.0%
# 1       2         탈주   2024-07-03  22,537,334,282            19.5%
# 2       3   데드풀과 울버린   2024-07-24  13,839,704,940            12.0%
# 3       4      핸섬가이즈   2024-06-26  12,116,866,192            10.5%
# 4       5     슈퍼배드 4   2024-07-24   7,685,485,124             6.7%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0   80,768,663,666  2,767,299           8,406,132        1,664    120,555
# 1   22,665,054,282  2,382,788           2,396,691        1,234    108,501
# 2   13,839,704,940  1,352,113           1,352,113        1,948     60,958
# 3   16,343,766,218  1,289,849           1,748,722        1,065     73,126
# 4    7,685,485,124    843,830             843,830        1,178     36,541
#
#   main_country country            distributor  month
# 0           미국      미국     월트디즈니컴퍼니코리아 유한책임회사  24.07
# ...

# %%
df.to_csv("240708.csv", index=False)

# %%
df=pd.read_csv("KOBIS_월별박스오피스_240910.csv")

# %%
df17 = df.iloc[7:650].reset_index(drop=True)
df17.head()
# Out:
#   ■ 월별 박스오피스  Unnamed: 1  Unnamed: 2     Unnamed: 3 Unnamed: 4  \
# 0          1        베테랑2  2024-09-13  9,870,120,218      16.1%
# 1          2  베놈: 라스트 댄스  2024-10-23  9,847,662,388      16.0%
# 2          3    대도시의 사랑법  2024-10-01  7,297,350,650      11.9%
# 3          4  조커: 폴리 아 되  2024-10-01  6,366,573,920      10.4%
# 4          5      와일드 로봇  2024-10-01  5,391,693,670       8.8%
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0  72,367,797,714  1,024,813  7,514,196      1,317     77,127          한국
# 1   9,847,662,388  1,005,411  1,005,411      1,663     59,063          미국
# 2   7,385,538,550    774,053    783,106      1,101     65,414          한국
# 3   6,377,181,920    611,371    611,995      1,385     45,742          미국
# 4   5,502,661,670    595,334    606,448      1,062     42,261          미국
#
#   Unnamed: 11               Unnamed: 12
# 0          한국                 (주)씨제이이엔엠
# 1          미국  소니픽쳐스엔터테인먼트코리아주식회사극장배급지점
# ...

# %%
df17.tail()
# Out:
#     ■ 월별 박스오피스           Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 638        612               살시뿌에데스         NaN          0       0.0%
# 639        612  The Night Won’t End         NaN          0       0.0%
# 640        612   대구청춘스펙트럼영화제 - 단편섹션         NaN          0       0.0%
# 641        612        구름이 그림자를 숨길 때         NaN          0       0.0%
# 642        612               회오리 바람  2010-02-25          0       0.0%
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 638          0          0          0          1          1          기타
# 639          0          0          0          1          1         카타르
# 640          0          0          0          1          1          한국
# 641          0          0          0          1          2          칠레
# 642          0          0          0          1          1          한국
#
#      Unnamed: 11 Unnamed: 12
# 638           기타         NaN
# 639          카타르         NaN
# ...

# %%
df18 = df.iloc[655:-1].reset_index(drop=True)
df18.head()
# Out:
#   ■ 월별 박스오피스  Unnamed: 1  Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0          1        베테랑2  2024-09-13  62,497,677,496      62.4%
# 1          2  에이리언: 로물루스  2024-08-14   4,400,663,791       4.4%
# 2          3     사랑의 하츄핑  2024-08-07   2,596,577,910       2.6%
# 3          4     안녕, 할부지  2024-09-04   2,281,541,639       2.3%
# 4          5         파일럿  2024-07-31   2,020,981,840       2.0%
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0  62,497,677,496  6,489,383  6,489,383      2,691    200,561          한국
# 1  20,405,247,130    438,500  1,998,630      1,009     41,535          미국
# 2  10,276,474,432    297,701  1,147,527        690     14,411          한국
# 3   2,317,495,639    246,581    250,528      1,021     28,065          한국
# 4  43,091,622,701    244,276  4,702,215        840     25,057          한국
#
#   Unnamed: 11         Unnamed: 12
# 0          한국           (주)씨제이이엔엠
# 1          미국  월트디즈니컴퍼니코리아 유한책임회사
# ...

# %%
df18.tail()
# Out:
#     ■ 월별 박스오피스                   Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 701        689                    판타지아전 섹션3         NaN          0       0.0%
# 702        689          차별없이 억압없이 배제없이 혐오없이         NaN          0       0.0%
# 703        689  제 16회 서울국제건축영화제 호스트 아키텍트 포럼         NaN          0       0.0%
# 704        689                          바얌섬  2025-10-29          0       0.0%
# 705        689                         애국소녀         NaN          0       0.0%
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 701          0          0          0          1          1          한국
# 702          0          0          0          1          1          한국
# 703          0          0          0          1          1          기타
# 704          0          0          0          1          1          한국
# 705  2,809,000          0        343          1          1          한국
#
#     Unnamed: 11 Unnamed: 12
# 701          한국         NaN
# ...

# %%
df17["month"]="24.10"
df18["month"]="24.09"

# %%
df17.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df17.head()
# Out:
#   ranking  movie_name release_date          sales sales_percentage  \
# 0       1        베테랑2   2024-09-13  9,870,120,218            16.1%
# 1       2  베놈: 라스트 댄스   2024-10-23  9,847,662,388            16.0%
# 2       3    대도시의 사랑법   2024-10-01  7,297,350,650            11.9%
# 3       4  조커: 폴리 아 되   2024-10-01  6,366,573,920            10.4%
# 4       5      와일드 로봇   2024-10-01  5,391,693,670             8.8%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0   72,367,797,714  1,024,813           7,514,196        1,317     77,127
# 1    9,847,662,388  1,005,411           1,005,411        1,663     59,063
# 2    7,385,538,550    774,053             783,106        1,101     65,414
# 3    6,377,181,920    611,371             611,995        1,385     45,742
# 4    5,502,661,670    595,334             606,448        1,062     42,261
#
#   main_country country               distributor  month
# 0           한국      한국                 (주)씨제이이엔엠  24.10
# ...

# %%
df18.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df18.head()
# Out:
#   ranking  movie_name release_date           sales sales_percentage  \
# 0       1        베테랑2   2024-09-13  62,497,677,496            62.4%
# 1       2  에이리언: 로물루스   2024-08-14   4,400,663,791             4.4%
# 2       3     사랑의 하츄핑   2024-08-07   2,596,577,910             2.6%
# 3       4     안녕, 할부지   2024-09-04   2,281,541,639             2.3%
# 4       5         파일럿   2024-07-31   2,020,981,840             2.0%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0   62,497,677,496  6,489,383           6,489,383        2,691    200,561
# 1   20,405,247,130    438,500           1,998,630        1,009     41,535
# 2   10,276,474,432    297,701           1,147,527          690     14,411
# 3    2,317,495,639    246,581             250,528        1,021     28,065
# 4   43,091,622,701    244,276           4,702,215          840     25,057
#
#   main_country country         distributor  month
# 0           한국      한국           (주)씨제이이엔엠  24.09
# ...

# %%
df = pd.concat([df18, df17])
df.head()
# Out:
#   ranking  movie_name release_date           sales sales_percentage  \
# 0       1        베테랑2   2024-09-13  62,497,677,496            62.4%
# 1       2  에이리언: 로물루스   2024-08-14   4,400,663,791             4.4%
# 2       3     사랑의 하츄핑   2024-08-07   2,596,577,910             2.6%
# 3       4     안녕, 할부지   2024-09-04   2,281,541,639             2.3%
# 4       5         파일럿   2024-07-31   2,020,981,840             2.0%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0   62,497,677,496  6,489,383           6,489,383        2,691    200,561
# 1   20,405,247,130    438,500           1,998,630        1,009     41,535
# 2   10,276,474,432    297,701           1,147,527          690     14,411
# 3    2,317,495,639    246,581             250,528        1,021     28,065
# 4   43,091,622,701    244,276           4,702,215          840     25,057
#
#   main_country country         distributor  month
# 0           한국      한국           (주)씨제이이엔엠  24.09
# ...

# %%
df.to_csv("240910.csv", index=False)

# %%
df=pd.read_csv("KOBIS_월별박스오피스_241112.csv")

# %%
df19 = df.iloc[7:735].reset_index(drop=True)
df19.head()
# Out:
#   ■ 월별 박스오피스  Unnamed: 1  Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0          1         소방관  2024-12-04  31,098,404,290      25.0%
# 1          2         하얼빈  2024-12-24  26,249,028,320      21.1%
# 2          3       모아나 2  2024-11-27  22,727,697,820      18.3%
# 3          4         위키드  2024-11-20   9,685,624,650       7.8%
# 4          5  무파사: 라이온 킹  2024-12-18   6,543,943,550       5.3%
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0  31,161,375,290  3,310,323  3,317,296      1,594    119,743          한국
# 1  26,249,028,320  2,755,236  2,755,236      2,125     72,494          한국
# 2  31,118,051,070  2,441,529  3,372,815      1,985     95,741          미국
# 3  20,277,702,850    987,630  2,059,163      1,151     44,301          미국
# 4   6,543,943,550    656,645    656,645      1,243     33,414          미국
#
#   Unnamed: 11          Unnamed: 12
# 0          한국          (주)바이포엠스튜디오
# 1          한국            (주)씨제이이엔엠
# ...

# %%
df19.tail()
# Out:
#     ■ 월별 박스오피스            Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 723        697   제1회 부산국제인공지능영화제 섹션5         NaN          0       0.0%
# 724        697   제1회 부산국제인공지능영화제 섹션6         NaN          0       0.0%
# 725        697            백야의 언약 상영회         NaN          0       0.0%
# 726        697  2024 한양대학교 졸업영화제 섹션1         NaN          0       0.0%
# 727        697               세기말의 사랑  2024-01-24          0       0.0%
#
#       Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 723            0          0          0          1          1          한국
# 724            0          0          0          1          1          기타
# 725            0          0          0          1          1          한국
# 726            0          0          0          1          1          한국
# 727  101,133,958          0     12,139          1          2          한국
#
#     Unnamed: 11         Unnamed: 12
# 723          한국                 NaN
# ...

# %%
df20 = df.iloc[740:-1].reset_index(drop=True)
df20.head()
# Out:
#   ■ 월별 박스오피스  Unnamed: 1  Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0          1         위키드  2024-11-20  10,592,078,200      16.0%
# 1          2       모아나 2  2024-11-27   8,390,353,250      12.7%
# 2          3    글래디에이터 Ⅱ  2024-11-13   8,219,618,370      12.4%
# 3          4          청설  2024-11-06   7,139,987,740      10.8%
# 4          5  베놈: 라스트 댄스  2024-10-23   7,350,822,100      11.1%
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0  10,592,078,200  1,071,533  1,071,533      1,803     50,949          미국
# 1   8,390,353,250    931,286    931,286      1,974     30,841          미국
# 2   8,221,729,370    841,741    841,964      1,769     57,272          미국
# 3   7,154,611,740    763,788    765,212      1,060     59,671          한국
# 4  17,198,484,488    752,212  1,757,623      1,326     59,389          미국
#
#   Unnamed: 11               Unnamed: 12
# 0          미국       유니버설픽쳐스인터내셔널 코리아(유)
# 1      미국,캐나다        월트디즈니컴퍼니코리아 유한책임회사
# ...

# %%
df20.tail()
# Out:
#     ■ 월별 박스오피스    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 896        844  바후발리: 더 컨클루전        NaN          0       0.0%           0
# 897        844      쓰리 오브 어스        NaN          0       0.0%           0
# 898        844           칸타라        NaN          0       0.0%           0
# 899        844      라파타 레이디스        NaN          0       0.0%           0
# 900        844          아이다호        NaN          0       0.0%  60,348,900
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 896          0          0          1          1          인도          인도
# 897          0          0          1          2          인도          인도
# 898          0          0          1          1          인도          인도
# 899          0          0          1          2          인도          인도
# 900          0      7,305          1          1          미국          미국
#
#     Unnamed: 12
# 896         NaN
# 897         NaN
# 898         NaN
# 899         NaN
# ...

# %%
df19["month"]="24.12"
df20["month"]="24.11"

# %%
df19.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df19.head()
# Out:
#   ranking  movie_name release_date           sales sales_percentage  \
# 0       1         소방관   2024-12-04  31,098,404,290            25.0%
# 1       2         하얼빈   2024-12-24  26,249,028,320            21.1%
# 2       3       모아나 2   2024-11-27  22,727,697,820            18.3%
# 3       4         위키드   2024-11-20   9,685,624,650             7.8%
# 4       5  무파사: 라이온 킹   2024-12-18   6,543,943,550             5.3%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0   31,161,375,290  3,310,323           3,317,296        1,594    119,743
# 1   26,249,028,320  2,755,236           2,755,236        2,125     72,494
# 2   31,118,051,070  2,441,529           3,372,815        1,985     95,741
# 3   20,277,702,850    987,630           2,059,163        1,151     44,301
# 4    6,543,943,550    656,645             656,645        1,243     33,414
#
#   main_country country          distributor  month
# 0           한국      한국          (주)바이포엠스튜디오  24.12
# ...

# %%
df20.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df20.head()
# Out:
#   ranking  movie_name release_date           sales sales_percentage  \
# 0       1         위키드   2024-11-20  10,592,078,200            16.0%
# 1       2       모아나 2   2024-11-27   8,390,353,250            12.7%
# 2       3    글래디에이터 Ⅱ   2024-11-13   8,219,618,370            12.4%
# 3       4          청설   2024-11-06   7,139,987,740            10.8%
# 4       5  베놈: 라스트 댄스   2024-10-23   7,350,822,100            11.1%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0   10,592,078,200  1,071,533           1,071,533        1,803     50,949
# 1    8,390,353,250    931,286             931,286        1,974     30,841
# 2    8,221,729,370    841,741             841,964        1,769     57,272
# 3    7,154,611,740    763,788             765,212        1,060     59,671
# 4   17,198,484,488    752,212           1,757,623        1,326     59,389
#
#   main_country country               distributor  month
# ...

# %%
df = pd.concat([df20, df19])
df.head()
# Out:
#   ranking  movie_name release_date           sales sales_percentage  \
# 0       1         위키드   2024-11-20  10,592,078,200            16.0%
# 1       2       모아나 2   2024-11-27   8,390,353,250            12.7%
# 2       3    글래디에이터 Ⅱ   2024-11-13   8,219,618,370            12.4%
# 3       4          청설   2024-11-06   7,139,987,740            10.8%
# 4       5  베놈: 라스트 댄스   2024-10-23   7,350,822,100            11.1%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0   10,592,078,200  1,071,533           1,071,533        1,803     50,949
# 1    8,390,353,250    931,286             931,286        1,974     30,841
# 2    8,221,729,370    841,741             841,964        1,769     57,272
# 3    7,154,611,740    763,788             765,212        1,060     59,671
# 4   17,198,484,488    752,212           1,757,623        1,326     59,389
#
#   main_country country               distributor  month
# ...

# %%
df.to_csv("241112.csv", index=False)

# %%
df=pd.read_csv("KOBIS_월별박스오피스_250102.csv")

# %%
df21 = df.iloc[7:450].reset_index(drop=True)
df21.head()
# Out:
#   ■ 월별 박스오피스          Unnamed: 1  Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0          1  캡틴 아메리카: 브레이브 뉴 월드  2025-02-12  14,554,372,506      27.4%
# 1          2                히트맨2  2025-01-22   8,360,342,240      15.7%
# 2          3          말할 수 없는 비밀  2025-01-27   5,534,030,180      10.4%
# 3          4              검은 수녀들  2025-01-24   3,838,046,760       7.2%
# 4          5               미키 17  2025-02-28   2,547,448,920       4.8%
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0  14,554,372,506  1,464,276  1,464,276      1,901    103,015          미국
# 1  23,937,166,980    887,949  2,542,377      1,495     66,343          한국
# 2   7,752,532,100    577,640    812,933        986     49,827          한국
# 3  16,109,391,280    398,774  1,666,571      1,192     37,147          한국
# 4   2,547,448,920    254,393    254,393      2,151      8,794          미국
#
#   Unnamed: 11            Unnamed: 12
# 0          미국     월트디즈니컴퍼니코리아 유한책임회사
# ...

# %%
df21.tail()
# Out:
#     ■ 월별 박스오피스 Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 438        436        반칙왕  2000-02-04          0       0.0%          0
# 439        436   서울의 지붕 밑         NaN          0       0.0%          0
# 440        436       삼등과장         NaN          0       0.0%          0
# 441        436          돈  1950-03-09          0       0.0%          0
# 442        436         뭉호         NaN          0       0.0%          0
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 438          0          0          1          2          한국          한국
# 439          0          0          1          2          한국          한국
# 440          0          0          1          2          한국          한국
# 441          0          0          1          2          한국          한국
# 442          0          0          1          2          몽고          몽고
#
#     Unnamed: 12
# 438   (주)시네마서비스
# 439         NaN
# 440         NaN
# 441         NaN
# 442         NaN

# %%
df22 = df.iloc[455:-1].reset_index(drop=True)
df22.head()
# Out:
#   ■ 월별 박스오피스       Unnamed: 1  Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0          1              하얼빈  2024-12-24  19,891,094,780      23.3%
# 1          2             히트맨2  2025-01-22  15,576,824,740      18.3%
# 2          3           검은 수녀들  2025-01-24  12,271,344,520      14.4%
# 3          4              소방관  2024-12-04   5,084,748,380       6.0%
# 4          5  뽀로로 극장판 바닷속 대모험  2025-01-01   2,926,095,680       3.4%
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0  46,140,123,100  2,068,563  4,823,799      1,425    116,074          한국
# 1  15,576,824,740  1,654,428  1,654,428      1,588     51,754          한국
# 2  12,271,344,520  1,267,797  1,267,797      1,662     47,087          한국
# 3  36,246,123,670    533,707  3,851,003        884     42,465          한국
# 4   3,242,433,070    342,639    376,594        791     21,977          한국
#
#   Unnamed: 11          Unnamed: 12
# 0          한국            (주)씨제이이엔엠
# ...

# %%
df22.tail()
# Out:
#     ■ 월별 박스오피스           Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 438        371  웹캠:성욕과 물터지는 섹시한 가정부  2025-01-31      6,000       0.0%
# 439        371  골 때리고 떡 때리는 그녀들: 후반  2025-01-24      1,000       0.0%
# 440        441                  귀여워  2004-11-26          0       0.0%
# 441        441          여자는 남자의 미래다  2004-05-05          0       0.0%
# 442        441                 하류인생  2004-05-21          0       0.0%
#
#         Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 438          6,000          1          1          1          1          일본
# 439          1,000          1          1          1          1          한국
# 440    327,309,000          0     51,284          1          2          한국
# 441    778,809,500          0    116,662          1          2          한국
# 442  1,471,268,000          0    224,856          1          2          한국
#
#     Unnamed: 11   Unnamed: 12
# 438          일본   (주)영진크리에이티브
# 439          한국  유한회사 영화사 반딧불
# ...

# %%
df21["month"]="25.02"
df22["month"]="25.01"

# %%
df21.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df21.head()
# Out:
#   ranking          movie_name release_date           sales sales_percentage  \
# 0       1  캡틴 아메리카: 브레이브 뉴 월드   2025-02-12  14,554,372,506            27.4%
# 1       2                히트맨2   2025-01-22   8,360,342,240            15.7%
# 2       3          말할 수 없는 비밀   2025-01-27   5,534,030,180            10.4%
# 3       4              검은 수녀들   2025-01-24   3,838,046,760             7.2%
# 4       5               미키 17   2025-02-28   2,547,448,920             4.8%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0   14,554,372,506  1,464,276           1,464,276        1,901    103,015
# 1   23,937,166,980    887,949           2,542,377        1,495     66,343
# 2    7,752,532,100    577,640             812,933          986     49,827
# 3   16,109,391,280    398,774           1,666,571        1,192     37,147
# 4    2,547,448,920    254,393             254,393        2,151      8,794
#
#   main_country country            distributor  month
# ...

# %%
df22.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df22.head()
# Out:
#   ranking       movie_name release_date           sales sales_percentage  \
# 0       1              하얼빈   2024-12-24  19,891,094,780            23.3%
# 1       2             히트맨2   2025-01-22  15,576,824,740            18.3%
# 2       3           검은 수녀들   2025-01-24  12,271,344,520            14.4%
# 3       4              소방관   2024-12-04   5,084,748,380             6.0%
# 4       5  뽀로로 극장판 바닷속 대모험   2025-01-01   2,926,095,680             3.4%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0   46,140,123,100  2,068,563           4,823,799        1,425    116,074
# 1   15,576,824,740  1,654,428           1,654,428        1,588     51,754
# 2   12,271,344,520  1,267,797           1,267,797        1,662     47,087
# 3   36,246,123,670    533,707           3,851,003          884     42,465
# 4    3,242,433,070    342,639             376,594          791     21,977
#
#   main_country country          distributor  month
# ...

# %%
df = pd.concat([df22, df21])
df.head()
# Out:
#   ranking       movie_name release_date           sales sales_percentage  \
# 0       1              하얼빈   2024-12-24  19,891,094,780            23.3%
# 1       2             히트맨2   2025-01-22  15,576,824,740            18.3%
# 2       3           검은 수녀들   2025-01-24  12,271,344,520            14.4%
# 3       4              소방관   2024-12-04   5,084,748,380             6.0%
# 4       5  뽀로로 극장판 바닷속 대모험   2025-01-01   2,926,095,680             3.4%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0   46,140,123,100  2,068,563           4,823,799        1,425    116,074
# 1   15,576,824,740  1,654,428           1,654,428        1,588     51,754
# 2   12,271,344,520  1,267,797           1,267,797        1,662     47,087
# 3   36,246,123,670    533,707           3,851,003          884     42,465
# 4    3,242,433,070    342,639             376,594          791     21,977
#
#   main_country country          distributor  month
# ...

# %%
df.to_csv("250102.csv", index=False)

# %%
df=pd.read_csv("KOBIS_월별박스오피스_250304.csv")

# %%
df23 = df.iloc[7:592].reset_index(drop=True)
df23.head()
# Out:
#   ■ 월별 박스오피스                   Unnamed: 1  Unnamed: 2      Unnamed: 3  \
# 0          1                           야당  2025-04-16  17,335,200,590
# 1          2                           승부  2025-03-26  12,678,579,880
# 2          3  A MINECRAFT MOVIE 마인크래프트 무비  2025-04-26   4,019,940,940
# 3          4                           로비  2025-04-02   2,413,028,740
# 4          5      극장판 진격의 거인 완결편 더 라스트 어택  2025-03-13   2,635,164,810
#
#   Unnamed: 4      Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0      33.9%  17,338,269,590  1,841,518  1,841,797      1,850    100,486
# 1      24.8%  19,805,992,760  1,350,527  2,119,764      1,548    105,224
# 2       7.9%   4,019,940,940    423,665    423,665      1,450     19,653
# 3       4.7%   2,456,403,340    255,534    260,151      1,013     32,929
# 4       5.2%   8,096,849,070    250,600    801,506        298     16,007
#
#   Unnamed: 10 Unnamed: 11            Unnamed: 12
# 0          한국          한국  메가박스중앙(주) 플러스엠 엔터테인먼트
# ...

# %%
df23.tail()
# Out:
#     ■ 월별 박스오피스         Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 580        575               리골레토  2020-04-05          0       0.0%
# 581        575            한국이 싫어서  2024-08-28          0       0.0%
# 582        575             딸에 대하여  2024-09-04          0       0.0%
# 583        575  제3회 강릉국제아트페스티벌 섹션         NaN          0       0.0%
# 584        575        광해, 왕이 된 남자  2012-09-13          0       0.0%
#
#       Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 580            0          0          0          1          1          독일
# 581            0          0          0          1          1          한국
# 582  198,493,780          0     21,858          1          1          한국
# 583            0          0          0          1          9          한국
# 584            0          0          0          1          1          한국
#
#     Unnamed: 11  Unnamed: 12
# 580          독일    (주)케빈앤컴퍼니
# 581          한국     (주)디스테이션
# ...

# %%
df24 = df.iloc[597:-1].reset_index(drop=True)
df24.head()
# Out:
#   ■ 월별 박스오피스               Unnamed: 1  Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0          1                    미키 17  2025-02-28  26,703,536,310      43.1%
# 1          2                       승부  2025-03-26   7,127,412,880      11.5%
# 2          3  극장판 진격의 거인 완결편 더 라스트 어택  2025-03-13   5,461,684,260       8.8%
# 3          4                      퇴마록  2025-02-21   2,736,497,180       4.4%
# 4          5                     콘클라베  2025-03-05   2,186,519,100       3.5%
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0  29,250,985,230  2,712,431  2,966,824      2,153    141,207          미국
# 1   7,127,412,880    769,237    769,237      1,773     42,711          한국
# 2   5,461,684,260    550,906    550,906        424     18,954          일본
# 3   4,663,601,900    288,325    491,363        935     28,656          한국
# 4   2,221,690,500    230,536    234,152        630     20,735          미국
#
#   Unnamed: 11    Unnamed: 12
# ...

# %%
df24.tail()
# Out:
#     ■ 월별 박스오피스         Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 431        432  제3회 강릉국제아트페스티벌 섹션         NaN          0       0.0%
# 432        432         구룡성채: 무법지대  2024-10-16          0       0.0%
# 433        432              우리 학교  2007-03-29          0       0.0%
# 434        432              다세포소녀  2006-08-10          0       0.0%
# 435        432       우리들의 일그러진 영웅  1992-08-15          0       0.0%
#
#         Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 431              0          0          0          1          9          한국
# 432     99,318,950          0     11,562          1          1          홍콩
# 433    213,869,000          0     34,852          1          2          한국
# 434  2,858,283,600          0    476,011          1          2          한국
# 435              0          0          0          1          2          한국
#
#     Unnamed: 11             Unnamed: 12
# 431          한국                     NaN
# ...

# %%
df23["month"]="25.04"
df24["month"]="25.03"

# %%
df23.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df23.head()
# Out:
#   ranking                   movie_name release_date           sales  \
# 0       1                           야당   2025-04-16  17,335,200,590
# 1       2                           승부   2025-03-26  12,678,579,880
# 2       3  A MINECRAFT MOVIE 마인크래프트 무비   2025-04-26   4,019,940,940
# 3       4                           로비   2025-04-02   2,413,028,740
# 4       5      극장판 진격의 거인 완결편 더 라스트 어택   2025-03-13   2,635,164,810
#
#   sales_percentage cumulative_sales   audience cumulative_audience  \
# 0            33.9%   17,338,269,590  1,841,518           1,841,797
# 1            24.8%   19,805,992,760  1,350,527           2,119,764
# 2             7.9%    4,019,940,940    423,665             423,665
# 3             4.7%    2,456,403,340    255,534             260,151
# 4             5.2%    8,096,849,070    250,600             801,506
#
#   screen_count show_count main_country country            distributor  month
# ...

# %%
df24.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df24.head()
# Out:
#   ranking               movie_name release_date           sales  \
# 0       1                    미키 17   2025-02-28  26,703,536,310
# 1       2                       승부   2025-03-26   7,127,412,880
# 2       3  극장판 진격의 거인 완결편 더 라스트 어택   2025-03-13   5,461,684,260
# 3       4                      퇴마록   2025-02-21   2,736,497,180
# 4       5                     콘클라베   2025-03-05   2,186,519,100
#
#   sales_percentage cumulative_sales   audience cumulative_audience  \
# 0            43.1%   29,250,985,230  2,712,431           2,966,824
# 1            11.5%    7,127,412,880    769,237             769,237
# 2             8.8%    5,461,684,260    550,906             550,906
# 3             4.4%    4,663,601,900    288,325             491,363
# 4             3.5%    2,221,690,500    230,536             234,152
#
#   screen_count show_count main_country country    distributor  month
# 0        2,153    141,207           미국      미국  워너브러더스 코리아(주)  25.03
# ...

# %%
df = pd.concat([df24, df23])
df.head()
# Out:
#   ranking               movie_name release_date           sales  \
# 0       1                    미키 17   2025-02-28  26,703,536,310
# 1       2                       승부   2025-03-26   7,127,412,880
# 2       3  극장판 진격의 거인 완결편 더 라스트 어택   2025-03-13   5,461,684,260
# 3       4                      퇴마록   2025-02-21   2,736,497,180
# 4       5                     콘클라베   2025-03-05   2,186,519,100
#
#   sales_percentage cumulative_sales   audience cumulative_audience  \
# 0            43.1%   29,250,985,230  2,712,431           2,966,824
# 1            11.5%    7,127,412,880    769,237             769,237
# 2             8.8%    5,461,684,260    550,906             550,906
# 3             4.4%    4,663,601,900    288,325             491,363
# 4             3.5%    2,221,690,500    230,536             234,152
#
#   screen_count show_count main_country country    distributor  month
# 0        2,153    141,207           미국      미국  워너브러더스 코리아(주)  25.03
# ...

# %%
df.tail()
# Out:
#     ranking         movie_name release_date sales sales_percentage  \
# 580     575               리골레토   2020-04-05     0             0.0%
# 581     575            한국이 싫어서   2024-08-28     0             0.0%
# 582     575             딸에 대하여   2024-09-04     0             0.0%
# 583     575  제3회 강릉국제아트페스티벌 섹션          NaN     0             0.0%
# 584     575        광해, 왕이 된 남자   2012-09-13     0             0.0%
#
#     cumulative_sales audience cumulative_audience screen_count show_count  \
# 580                0        0                   0            1          1
# 581                0        0                   0            1          1
# 582      198,493,780        0              21,858            1          1
# 583                0        0                   0            1          9
# 584                0        0                   0            1          1
#
#     main_country country  distributor  month
# 580           독일      독일    (주)케빈앤컴퍼니  25.04
# ...

# %%
df.to_csv("250304.csv", index=False)

# %%
df=pd.read_csv("KOBIS_월별박스오피스_250506.csv")

# %%
df25 = df.iloc[7:678].reset_index(drop=True)
df25.head()
# Out:
#   ■ 월별 박스오피스        Unnamed: 1  Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0          1             하이파이브  2025-05-30  14,925,913,580      20.2%
# 1          2          드래곤 길들이기  2025-06-06  15,566,398,960      21.1%
# 2          3  미션 임파서블: 파이널 레코닝  2025-05-17   9,883,322,550      13.4%
# 3          4                신명  2025-06-02   7,042,863,160       9.5%
# 4          5           F1 더 무비  2025-06-25   5,765,519,060       7.8%
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0  17,159,791,010  1,612,363  1,849,352      1,343     89,153          한국
# 1  15,611,823,960  1,544,510  1,547,247      1,650     78,571          미국
# 2  32,948,734,860  1,025,274  3,360,001      1,365     53,463          미국
# 3   7,179,717,660    739,317    752,149        785     36,676          한국
# 4   5,765,519,060    534,899    534,899      1,665     30,339          미국
#
#   Unnamed: 11                       Unnamed: 12
# 0          한국               (주)넥스트엔터테인먼트월드(NEW)
# ...

# %%
df25.tail()
# Out:
#     ■ 월별 박스오피스 Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 666        646       수학여행         NaN          0       0.0%          0
# 667        646     사람의 아들  1981-01-01          0       0.0%          0
# 668        646     장미빛 인생  1994-08-06          0       0.0%          0
# 669        646     조용한 가족  1998-04-25          0       0.0%          0
# 670        646        미도리         NaN          0       0.0%          0
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 666          0          0          1          1          한국          한국
# 667          0          0          1          1          한국          한국
# 668          0          0          1          2          한국          한국
# 669          0          0          1          2          한국          한국
# 670          0          0          1          1          일본          일본
#
#     Unnamed: 12
# 666         NaN
# 667         NaN
# 668         NaN
# 669         NaN
# 670         NaN

# %%
df26 = df.iloc[683:-1].reset_index(drop=True)
df26.head()
# Out:
#   ■ 월별 박스오피스                   Unnamed: 1  Unnamed: 2      Unnamed: 3  \
# 0          1             미션 임파서블: 파이널 레코닝  2025-05-17  23,065,412,310
# 1          2                           야당  2025-04-16  14,530,617,340
# 2          3  A MINECRAFT MOVIE 마인크래프트 무비  2025-04-26   8,637,220,530
# 3          4                        썬더볼츠＊  2025-04-30   8,343,968,950
# 4          5                거룩한 밤: 데몬 헌터스  2025-04-30   6,230,473,900
#
#   Unnamed: 4      Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0      28.0%  23,065,412,310  2,334,727  2,334,727      2,385     94,508
# 1      17.6%  31,868,886,930  1,522,463  3,364,260      1,441     81,704
# 2      10.5%  12,657,161,470    925,266  1,348,931      1,415     35,778
# 3      10.1%   9,259,331,560    818,769    920,192      1,236     52,501
# 4       7.6%   7,203,375,200    655,989    777,308      1,097     36,071
#
#   Unnamed: 10 Unnamed: 11            Unnamed: 12
# 0          미국          미국      롯데컬처웍스(주)롯데엔터테인먼트
# ...

# %%
df26.tail()
# Out:
#     ■ 월별 박스오피스   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 618        578    붉은 아이들의 길        NaN          0       0.0%          0
# 619        578           예언        NaN          0       0.0%          0
# 620        578  어부와 말하는 물고기        NaN          0       0.0%          0
# 621        578          여자들        NaN          0       0.0%          0
# 622        578      굿바이 줄리아        NaN          0       0.0%    480,000
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  Unnamed: 11  \
# 618          0          0          1          2          기타   기타,프랑스,벨기에
# 619          0          0          1          2          기타  기타,벨기에,네덜란드
# 620          0          0          1          1          기타           기타
# 621          0          0          1          2          기타           기타
# 622          0        160          1          3          기타           기타
#
#     Unnamed: 12
# 618         NaN
# 619         NaN
# 620         NaN
# 621         NaN
# ...

# %%
df25["month"]="25.06"
df26["month"]="25.05"

# %%
df25.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df25.head()
# Out:
#   ranking        movie_name release_date           sales sales_percentage  \
# 0       1             하이파이브   2025-05-30  14,925,913,580            20.2%
# 1       2          드래곤 길들이기   2025-06-06  15,566,398,960            21.1%
# 2       3  미션 임파서블: 파이널 레코닝   2025-05-17   9,883,322,550            13.4%
# 3       4                신명   2025-06-02   7,042,863,160             9.5%
# 4       5           F1 더 무비   2025-06-25   5,765,519,060             7.8%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0   17,159,791,010  1,612,363           1,849,352        1,343     89,153
# 1   15,611,823,960  1,544,510           1,547,247        1,650     78,571
# 2   32,948,734,860  1,025,274           3,360,001        1,365     53,463
# 3    7,179,717,660    739,317             752,149          785     36,676
# 4    5,765,519,060    534,899             534,899        1,665     30,339
#
#   main_country country                       distributor  month
# ...

# %%
df26.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df26.head()
# Out:
#   ranking                   movie_name release_date           sales  \
# 0       1             미션 임파서블: 파이널 레코닝   2025-05-17  23,065,412,310
# 1       2                           야당   2025-04-16  14,530,617,340
# 2       3  A MINECRAFT MOVIE 마인크래프트 무비   2025-04-26   8,637,220,530
# 3       4                        썬더볼츠＊   2025-04-30   8,343,968,950
# 4       5                거룩한 밤: 데몬 헌터스   2025-04-30   6,230,473,900
#
#   sales_percentage cumulative_sales   audience cumulative_audience  \
# 0            28.0%   23,065,412,310  2,334,727           2,334,727
# 1            17.6%   31,868,886,930  1,522,463           3,364,260
# 2            10.5%   12,657,161,470    925,266           1,348,931
# 3            10.1%    9,259,331,560    818,769             920,192
# 4             7.6%    7,203,375,200    655,989             777,308
#
#   screen_count show_count main_country country            distributor  month
# ...

# %%
df = pd.concat([df26, df25])

# %%
df.head()
# Out:
#   ranking                   movie_name release_date           sales  \
# 0       1             미션 임파서블: 파이널 레코닝   2025-05-17  23,065,412,310
# 1       2                           야당   2025-04-16  14,530,617,340
# 2       3  A MINECRAFT MOVIE 마인크래프트 무비   2025-04-26   8,637,220,530
# 3       4                        썬더볼츠＊   2025-04-30   8,343,968,950
# 4       5                거룩한 밤: 데몬 헌터스   2025-04-30   6,230,473,900
#
#   sales_percentage cumulative_sales   audience cumulative_audience  \
# 0            28.0%   23,065,412,310  2,334,727           2,334,727
# 1            17.6%   31,868,886,930  1,522,463           3,364,260
# 2            10.5%   12,657,161,470    925,266           1,348,931
# 3            10.1%    9,259,331,560    818,769             920,192
# 4             7.6%    7,203,375,200    655,989             777,308
#
#   screen_count show_count main_country country            distributor  month
# ...

# %%
df.to_csv("250506.csv", index=False)

# %%
df=pd.read_csv("KOBIS_월별박스오피스_250708.csv")

# %%
df27 = df.iloc[7:755].reset_index(drop=True)
df27.head()
# Out:
#   ■ 월별 박스오피스        Unnamed: 1  Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0          1               좀비딸  2025-07-30  44,745,898,810      33.0%
# 1          2  극장판 귀멸의 칼날: 무한성편  2025-08-22  34,047,039,980      25.1%
# 2          3           F1 더 무비  2025-06-25  22,241,743,450      16.4%
# 3          4           킹 오브 킹스  2025-07-16   3,969,127,900       2.9%
# 4          5          악마가 이사왔다  2025-08-13   3,963,230,310       2.9%
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0  50,677,473,110  4,644,095  5,347,076      1,598    151,123          한국
# 1  34,047,039,980  3,153,718  3,153,718      2,298     74,827          일본
# 2  51,134,093,100  2,048,088  4,760,384        981     66,530          미국
# 3  12,226,901,076    419,093  1,296,035        814     18,221          한국
# 4   3,963,230,310    417,227    417,227        974     30,705          한국
#
#   Unnamed: 11          Unnamed: 12
# 0          한국  (주)넥스트엔터테인먼트월드(NEW)
# ...

# %%
df27.tail()
# Out:
#     ■ 월별 박스오피스                                        Unnamed: 1  Unnamed: 2  \
# 743        734  2025 로컬-시내(Ciné) : 지역영화 교류전 - 섹션2 WOMEN IN FOCUS         NaN
# 744        734        2025 로컬-시내(Ciné) : 지역영화 교류전 - 섹션3 DREAMERS         NaN
# 745        734           2025 로컬-시내(Ciné) : 지역영화 교류전 - 섹션1 YOUTH         NaN
# 746        734         2025 로컬-시내(Ciné) : 지역영화 교류전 - 섹션4 REALITY         NaN
# 747        734                                            육체의 약속  1975-07-26
#
#     Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 743          0       0.0%          0          0          0          1
# 744          0       0.0%          0          0          0          1
# 745          0       0.0%          0          0          0          1
# 746          0       0.0%          0          0          0          1
# 747          0       0.0%          0          0          0          1
#
#     Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12
# ...

# %%
df28 = df.iloc[760:-1].reset_index(drop=True)
df28.head()
# Out:
#   ■ 월별 박스오피스      Unnamed: 1  Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0          1  쥬라기 월드: 새로운 시작  2025-07-02  20,937,554,270      18.2%
# 1          2         F1 더 무비  2025-06-25  23,126,830,590      20.1%
# 2          3             노이즈  2025-06-25  14,214,389,760      12.4%
# 3          4         킹 오브 킹스  2025-07-16   8,237,623,176       7.2%
# 4          5       전지적 독자 시점  2025-07-23   8,356,959,660       7.3%
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0  20,946,092,270  2,197,632  2,198,202      1,645     86,451          미국
# 1  28,892,349,650  2,177,397  2,712,296      1,382     69,260          미국
# 2  16,454,268,630  1,445,177  1,678,135      1,001     59,840          한국
# 3   8,257,773,176    875,009    876,942      1,191     33,337          한국
# 4   8,356,959,660    857,450    857,450      1,581     37,963          한국
#
#   Unnamed: 11          Unnamed: 12
# 0          미국  유니버설픽쳐스인터내셔널 코리아(유)
# 1          미국        워너브러더스 코리아(주)
# ...

# %%
df28.tail()
# Out:
#     ■ 월별 박스오피스 Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 655        647  막차로 온 손님들         NaN          0       0.0%    908,000
# 656        647     카인의 후예         NaN          0       0.0%          0
# 657        647       수학여행         NaN          0       0.0%          0
# 658        647         장마         NaN          0       0.0%  9,697,000
# 659        647    그대와 영원히  1958-01-15          0       0.0%  5,772,500
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 655          0        454          1          2          한국          한국
# 656          0          0          1          1          한국          한국
# 657          0          0          1          1          한국          한국
# 658          0      4,843          1          2          한국          한국
# 659          0      2,721          1          1          한국          한국
#
#     Unnamed: 12
# 655         NaN
# 656         NaN
# 657         NaN
# 658    (주)프리즘웍스
# 659         NaN

# %%
df27["month"]="25.08"
df28["month"]="25.07"

# %%
df27.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df27.head()
# Out:
#   ranking        movie_name release_date           sales sales_percentage  \
# 0       1               좀비딸   2025-07-30  44,745,898,810            33.0%
# 1       2  극장판 귀멸의 칼날: 무한성편   2025-08-22  34,047,039,980            25.1%
# 2       3           F1 더 무비   2025-06-25  22,241,743,450            16.4%
# 3       4           킹 오브 킹스   2025-07-16   3,969,127,900             2.9%
# 4       5          악마가 이사왔다   2025-08-13   3,963,230,310             2.9%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0   50,677,473,110  4,644,095           5,347,076        1,598    151,123
# 1   34,047,039,980  3,153,718           3,153,718        2,298     74,827
# 2   51,134,093,100  2,048,088           4,760,384          981     66,530
# 3   12,226,901,076    419,093           1,296,035          814     18,221
# 4    3,963,230,310    417,227             417,227          974     30,705
#
#   main_country country          distributor  month
# ...

# %%
df28.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df28.head()
# Out:
#   ranking      movie_name release_date           sales sales_percentage  \
# 0       1  쥬라기 월드: 새로운 시작   2025-07-02  20,937,554,270            18.2%
# 1       2         F1 더 무비   2025-06-25  23,126,830,590            20.1%
# 2       3             노이즈   2025-06-25  14,214,389,760            12.4%
# 3       4         킹 오브 킹스   2025-07-16   8,237,623,176             7.2%
# 4       5       전지적 독자 시점   2025-07-23   8,356,959,660             7.3%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0   20,946,092,270  2,197,632           2,198,202        1,645     86,451
# 1   28,892,349,650  2,177,397           2,712,296        1,382     69,260
# 2   16,454,268,630  1,445,177           1,678,135        1,001     59,840
# 3    8,257,773,176    875,009             876,942        1,191     33,337
# 4    8,356,959,660    857,450             857,450        1,581     37,963
#
#   main_country country          distributor  month
# ...

# %%
df = pd.concat([df28, df27])
df.head()
# Out:
#   ranking      movie_name release_date           sales sales_percentage  \
# 0       1  쥬라기 월드: 새로운 시작   2025-07-02  20,937,554,270            18.2%
# 1       2         F1 더 무비   2025-06-25  23,126,830,590            20.1%
# 2       3             노이즈   2025-06-25  14,214,389,760            12.4%
# 3       4         킹 오브 킹스   2025-07-16   8,237,623,176             7.2%
# 4       5       전지적 독자 시점   2025-07-23   8,356,959,660             7.3%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0   20,946,092,270  2,197,632           2,198,202        1,645     86,451
# 1   28,892,349,650  2,177,397           2,712,296        1,382     69,260
# 2   16,454,268,630  1,445,177           1,678,135        1,001     59,840
# 3    8,257,773,176    875,009             876,942        1,191     33,337
# 4    8,356,959,660    857,450             857,450        1,581     37,963
#
#   main_country country          distributor  month
# ...

# %%
df.to_csv("250708.csv", index=False)

# %%
df=pd.read_csv("KOBIS_월별박스오피스_250910.csv")

# %%
df29 = df.iloc[7:883].reset_index(drop=True)
df29.head()
# Out:
#   ■ 월별 박스오피스        Unnamed: 1  Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0          1                보스  2025-10-03  23,122,825,490      23.5%
# 1          2    극장판 체인소 맨: 레제편  2025-09-24  22,189,517,940      22.6%
# 2          3            어쩔수가없다  2025-09-24  16,367,343,620      16.7%
# 3          4  극장판 귀멸의 칼날: 무한성편  2025-08-22   5,358,829,390       5.5%
# 4          5      원 배틀 애프터 어나더  2025-10-01   5,393,791,240       5.5%
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0  23,167,398,990  2,407,846  2,412,606      1,296     94,008          한국
# 1  28,317,601,570  2,095,675  2,675,054        998     89,330          일본
# 2  28,403,760,090  1,670,838  2,905,075      1,353     74,795          한국
# 3  59,898,105,010    523,088  5,549,749        635     22,420          일본
# 4   5,427,443,740    507,628    509,912        657     25,461          미국
#
#   Unnamed: 11               Unnamed: 12
# 0          한국      (주)하이브미디어코프,(주)마인드마크
# ...

# %%
df29.tail()
# Out:
#     ■ 월별 박스오피스       Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 871        848          빌리 엘리어트  2001-02-16          0       0.0%          0
# 872        848          아무도 모른다  2005-04-01          0       0.0%          0
# 873        848              미망인  1955-12-10          0       0.0%          0
# 874        848       돌아오지 않는 해병         NaN          0       0.0%          0
# 875        848  16회 부산평화영화제 폐막식         NaN          0       0.0%          0
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 871          0          0          1          2          영국      영국,프랑스
# 872          0          0          1          1          일본          일본
# 873          0          0          1          1          한국          한국
# 874          0          0          1          2          한국          한국
# 875          0          0          1          1          기타          기타
#
#                          Unnamed: 12
# ...

# %%
df30 = df.iloc[888:-1].reset_index(drop=True)
df30.head()
# Out:
#   ■ 월별 박스오피스        Unnamed: 1  Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0          1  극장판 귀멸의 칼날: 무한성편  2025-08-22  20,492,235,640      26.3%
# 1          2            어쩔수가없다  2025-09-24  12,035,520,470      15.5%
# 2          3                얼굴  2025-09-11   9,599,367,010      12.3%
# 3          4    극장판 체인소 맨: 레제편  2025-09-24   6,128,083,630       7.9%
# 4          5       컨저링: 마지막 의식  2025-09-03   4,419,577,290       5.7%
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0  54,539,275,620  1,872,943  5,026,661      1,761     97,946          일본
# 1  12,036,416,470  1,234,173  1,234,237      2,114     47,093          한국
# 2   9,599,367,010    932,553    932,553      1,114     53,480          한국
# 3   6,128,083,630    579,379    579,379      1,064     21,662          일본
# 4   4,423,114,290    419,157    419,502        917     27,094          미국
#
#   Unnamed: 11               Unnamed: 12
# 0          일본                 (주)씨제이이엔엠
# ...

# %%
df30.tail()
# Out:
#     ■ 월별 박스오피스   Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4   Unnamed: 5  \
# 825        812  지역의 기억 - 단편         NaN          0       0.0%            0
# 826        812            깁         NaN          0       0.0%            0
# 827        812    김종관 단편선 1         NaN          0       0.0%            0
# 828        812    김종관 단편선 2         NaN          0       0.0%            0
# 829        812       최악의 하루  2016-08-25          0       0.0%  648,824,890
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 825          0          0          1          1          한국          한국
# 826          0          0          1          1          한국          한국
# 827          0          0          1          1          한국          한국
# 828          0          0          1          1          한국          한국
# 829          0     81,919          1          1          한국          한국
#
#     Unnamed: 12
# 825         NaN
# 826         NaN
# 827         NaN
# ...

# %%
df29["month"]="25.10"
df30["month"]="25.09"

# %%
df29.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df29.head()
# Out:
#   ranking        movie_name release_date           sales sales_percentage  \
# 0       1                보스   2025-10-03  23,122,825,490            23.5%
# 1       2    극장판 체인소 맨: 레제편   2025-09-24  22,189,517,940            22.6%
# 2       3            어쩔수가없다   2025-09-24  16,367,343,620            16.7%
# 3       4  극장판 귀멸의 칼날: 무한성편   2025-08-22   5,358,829,390             5.5%
# 4       5      원 배틀 애프터 어나더   2025-10-01   5,393,791,240             5.5%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0   23,167,398,990  2,407,846           2,412,606        1,296     94,008
# 1   28,317,601,570  2,095,675           2,675,054          998     89,330
# 2   28,403,760,090  1,670,838           2,905,075        1,353     74,795
# 3   59,898,105,010    523,088           5,549,749          635     22,420
# 4    5,427,443,740    507,628             509,912          657     25,461
#
#   main_country country               distributor  month
# ...

# %%
df30.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df30.head()
# Out:
#   ranking        movie_name release_date           sales sales_percentage  \
# 0       1  극장판 귀멸의 칼날: 무한성편   2025-08-22  20,492,235,640            26.3%
# 1       2            어쩔수가없다   2025-09-24  12,035,520,470            15.5%
# 2       3                얼굴   2025-09-11   9,599,367,010            12.3%
# 3       4    극장판 체인소 맨: 레제편   2025-09-24   6,128,083,630             7.9%
# 4       5       컨저링: 마지막 의식   2025-09-03   4,419,577,290             5.7%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0   54,539,275,620  1,872,943           5,026,661        1,761     97,946
# 1   12,036,416,470  1,234,173           1,234,237        2,114     47,093
# 2    9,599,367,010    932,553             932,553        1,114     53,480
# 3    6,128,083,630    579,379             579,379        1,064     21,662
# 4    4,423,114,290    419,157             419,502          917     27,094
#
#   main_country country               distributor  month
# ...

# %%
df = pd.concat([df30, df29])

# %%
df.head()
# Out:
#   ranking        movie_name release_date           sales sales_percentage  \
# 0       1  극장판 귀멸의 칼날: 무한성편   2025-08-22  20,492,235,640            26.3%
# 1       2            어쩔수가없다   2025-09-24  12,035,520,470            15.5%
# 2       3                얼굴   2025-09-11   9,599,367,010            12.3%
# 3       4    극장판 체인소 맨: 레제편   2025-09-24   6,128,083,630             7.9%
# 4       5       컨저링: 마지막 의식   2025-09-03   4,419,577,290             5.7%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0   54,539,275,620  1,872,943           5,026,661        1,761     97,946
# 1   12,036,416,470  1,234,173           1,234,237        2,114     47,093
# 2    9,599,367,010    932,553             932,553        1,114     53,480
# 3    6,128,083,630    579,379             579,379        1,064     21,662
# 4    4,423,114,290    419,157             419,502          917     27,094
#
#   main_country country               distributor  month
# ...

# %%
df.to_csv("250910.csv", index=False)

# %%
df=pd.read_csv("KOBIS_월별박스오피스_251112.csv")

# %%
df31 = df.iloc[7:854].reset_index(drop=True)
df31.head()
# Out:
#   ■ 월별 박스오피스                Unnamed: 1  Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0          1                    주토피아 2  2025-11-26  53,971,262,890      38.5%
# 1          2                 아바타: 불과 재  2025-12-17  52,409,899,290      37.4%
# 2          3                    윗집 사람들  2025-12-03   5,186,086,360       3.7%
# 3          4  오늘 밤, 세계에서 이 사랑이 사라진다 해도  2025-12-24   4,681,536,750       3.3%
# 4          5    극장판 주술회전: 시부야사변 X 사멸회유  2025-12-03   3,628,196,350       2.6%
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0  74,124,615,600  5,598,839  7,705,705      2,282    180,184          미국
# 1  52,409,899,290  4,569,538  4,569,538      2,582    102,298          미국
# 2   5,284,239,800    537,349    546,584        768     32,522          한국
# 3   4,681,536,750    489,021    489,021        868     15,093          한국
# 4   3,648,294,490    357,977    359,636        756     22,831          일본
#
#   Unnamed: 11         Unnamed: 12
# ...

# %%
df31.tail()
# Out:
#     ■ 월별 박스오피스  Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 842        843    네 멋대로 해라  2026-01-14   -133,000       0.0%  9,842,500
# 843        843          누룩  2026-04-15   -130,000       0.0%     80,000
# 844        845      리버 리턴즈         NaN   -190,000       0.0%   -190,000
# 845        846         마젤란         NaN   -260,000       0.0%   -590,000
# 846        847  사무라이 타임슬리퍼         NaN   -270,000       0.0%   -270,000
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 842        -13      3,272          1          1         프랑스
# 843        -13          8          1          1          한국
# 844        -19        -19          1          2          일본
# 845        -26        -59          1          1        포르투갈
# 846        -27        -27          1          2          일본
#
#              Unnamed: 11 Unnamed: 12
# 842                  프랑스   주식회사 오디언스
# 843                   한국   (주)로드쇼플러스
# 844                   일본         NaN
# ...

# %%
df32 = df.iloc[859:-1].reset_index(drop=True)
df32.head()
# Out:
#   ■ 월별 박스오피스      Unnamed: 1  Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0          1          주토피아 2  2025-11-26  20,153,352,710      27.9%
# 1          2      나우 유 씨 미 3  2025-11-12  11,862,578,410      16.4%
# 2          3        위키드: 포 굿  2025-11-19   8,055,284,900      11.1%
# 3          4  극장판 체인소 맨: 레제편  2025-09-24   6,908,716,120       9.6%
# 4          5         퍼스트 라이드  2025-10-29   5,215,126,930       7.2%
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0  20,153,352,710  2,106,866  2,106,866      2,383     45,432          미국
# 1  11,862,578,410  1,252,092  1,252,092      1,352     65,344          미국
# 2   8,055,284,900    781,928    781,928      1,700     48,403          미국
# 3  35,226,317,690    674,629  3,349,683        817     48,534          일본
# 4   6,822,441,490    553,192    739,689      1,166     46,249          한국
#
#   Unnamed: 11                    Unnamed: 12
# 0          미국             월트디즈니컴퍼니코리아 유한책임회사
# ...

# %%
df32.tail()
# Out:
#     ■ 월별 박스오피스            Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 959        960  SIFF2025-페스티벌초이스 단편7        NaN    -90,000       0.0%
# 960        961               다른 이름으로        NaN   -110,000       0.0%
# 961        962  SIFF2025-페스티벌초이스 단편5        NaN   -162,500       0.0%
# 962        963                  전망세대        NaN   -200,000       0.0%
# 963        964                   마젤란        NaN   -330,000       0.0%
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 959    -90,000         -9         -9          1          1          한국
# 960    890,000        -11        189          1          1          한국
# 961   -162,500        -16        -16          1          1          한국
# 962   -200,000        -20        -20          1          1          일본
# 963   -330,000        -33        -33          1          1        포르투갈
#
#              Unnamed: 11 Unnamed: 12
# 959                   한국         NaN
# 960                   한국         NaN
# ...

# %%
df31["month"]="25.12"
df32["month"]="25.11"

# %%
df31.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df31.head()
# Out:
#   ranking                movie_name release_date           sales  \
# 0       1                    주토피아 2   2025-11-26  53,971,262,890
# 1       2                 아바타: 불과 재   2025-12-17  52,409,899,290
# 2       3                    윗집 사람들   2025-12-03   5,186,086,360
# 3       4  오늘 밤, 세계에서 이 사랑이 사라진다 해도   2025-12-24   4,681,536,750
# 4       5    극장판 주술회전: 시부야사변 X 사멸회유   2025-12-03   3,628,196,350
#
#   sales_percentage cumulative_sales   audience cumulative_audience  \
# 0            38.5%   74,124,615,600  5,598,839           7,705,705
# 1            37.4%   52,409,899,290  4,569,538           4,569,538
# 2             3.7%    5,284,239,800    537,349             546,584
# 3             3.3%    4,681,536,750    489,021             489,021
# 4             2.6%    3,648,294,490    357,977             359,636
#
#   screen_count show_count main_country country         distributor  month
# 0        2,282    180,184           미국      미국  월트디즈니컴퍼니코리아 유한책임회사  25.12
# ...

# %%
df32.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df32.head()
# Out:
#   ranking      movie_name release_date           sales sales_percentage  \
# 0       1          주토피아 2   2025-11-26  20,153,352,710            27.9%
# 1       2      나우 유 씨 미 3   2025-11-12  11,862,578,410            16.4%
# 2       3        위키드: 포 굿   2025-11-19   8,055,284,900            11.1%
# 3       4  극장판 체인소 맨: 레제편   2025-09-24   6,908,716,120             9.6%
# 4       5         퍼스트 라이드   2025-10-29   5,215,126,930             7.2%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0   20,153,352,710  2,106,866           2,106,866        2,383     45,432
# 1   11,862,578,410  1,252,092           1,252,092        1,352     65,344
# 2    8,055,284,900    781,928             781,928        1,700     48,403
# 3   35,226,317,690    674,629           3,349,683          817     48,534
# 4    6,822,441,490    553,192             739,689        1,166     46,249
#
#   main_country country                    distributor  month
# ...

# %%
df = pd.concat([df32, df31])
df.head()
# Out:
#   ranking      movie_name release_date           sales sales_percentage  \
# 0       1          주토피아 2   2025-11-26  20,153,352,710            27.9%
# 1       2      나우 유 씨 미 3   2025-11-12  11,862,578,410            16.4%
# 2       3        위키드: 포 굿   2025-11-19   8,055,284,900            11.1%
# 3       4  극장판 체인소 맨: 레제편   2025-09-24   6,908,716,120             9.6%
# 4       5         퍼스트 라이드   2025-10-29   5,215,126,930             7.2%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0   20,153,352,710  2,106,866           2,106,866        2,383     45,432
# 1   11,862,578,410  1,252,092           1,252,092        1,352     65,344
# 2    8,055,284,900    781,928             781,928        1,700     48,403
# 3   35,226,317,690    674,629           3,349,683          817     48,534
# 4    6,822,441,490    553,192             739,689        1,166     46,249
#
#   main_country country                    distributor  month
# ...

# %%
df.to_csv("251112.csv", index=False)

# %%
df=pd.read_csv("KOBIS_월별박스오피스_260102.csv")

# %%
df33 = df.iloc[7:621].reset_index(drop=True)
df33.head()
# Out:
#   ■ 월별 박스오피스 Unnamed: 1  Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0          1   왕과 사는 남자  2026-02-04  73,493,037,620      62.0%
# 1          2        휴민트  2026-02-11  17,802,011,580      15.0%
# 2          3       신의악단  2025-12-31   4,901,114,260       4.1%
# 3          4     만약에 우리  2025-12-31   3,430,645,850       2.9%
# 4          5        넘버원  2026-02-11   2,523,309,980       2.1%
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0  73,742,894,090  7,641,781  7,667,180      2,165    179,807          한국
# 1  17,818,289,580  1,766,508  1,767,510      1,520     74,117          한국
# 2  13,172,979,710    512,586  1,381,202        893     26,420          한국
# 3  25,465,066,210    339,554  2,598,458        923     26,127          한국
# 4   2,530,164,980    263,905    264,607        652     17,255          한국
#
#   Unnamed: 11          Unnamed: 12
# 0          한국               (주)쇼박스
# 1          한국  (주)넥스트엔터테인먼트월드(NEW)
# ...

# %%
df33.tail()
# Out:
#     ■ 월별 박스오피스    Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 609        594  달은...해가 꾸는 꿈  1992-02-29          0       0.0%          0
# 610        594            파고  1997-03-15          0       0.0%          0
# 611        594     8월의 크리스마스  1998-01-24          0       0.0%          0
# 612        594   죽거나 혹은 나쁘거나  2000-07-15          0       0.0%          0
# 613        594   엄마를 버리러 갑니다  2025-11-05          0       0.0%          0
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 609          0          0          1          2          한국          한국
# 610          0          0          1          1          미국          미국
# 611          0          0          1          2          한국          한국
# 612          0          0          1          2          한국          한국
# 613          0          0          1          1          한국      한국,베트남
#
#              Unnamed: 12
# 609                  NaN
# 610                  NaN
# ...

# %%
df34 = df.iloc[626:-1].reset_index(drop=True)
df34.head()
# Out:
#   ■ 월별 박스오피스                Unnamed: 1  Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0          1                    만약에 우리  2025-12-31  20,926,257,000      24.5%
# 1          2                 아바타: 불과 재  2025-12-17  25,385,921,530      29.7%
# 2          3                    주토피아 2  2025-11-26   8,220,197,870       9.6%
# 3          4                      신의악단  2025-12-31   8,075,984,490       9.5%
# 4          5  오늘 밤, 세계에서 이 사랑이 사라진다 해도  2025-12-24   3,651,424,140       4.3%
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0  22,034,420,360  2,129,768  2,258,904      1,116    101,286          한국
# 1  77,795,820,820  2,085,863  6,655,401      1,761     89,685          미국
# 2  82,344,813,470    850,524  8,556,229        986     45,464          미국
# 3   8,271,865,450    843,984    868,616        907     39,027          한국
# 4   8,332,960,890    370,974    859,995        743     22,504          한국
#
#   Unnamed: 11          Unnamed: 12
# ...

# %%
df34.tail()
# Out:
#     ■ 월별 박스오피스    Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 648        467        감독의 딸들  2026-01-26      1,000       0.0%
# 649        650           황진이  1986-09-18          0       0.0%
# 650        650  돼지가 우물에 빠진 날  1996-05-15          0       0.0%
# 651        650           왕십리  1976-01-31          0       0.0%
# 652        650     그대를 사랑합니다  2011-02-17          0       0.0%
#
#          Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 648           1,000          1          1          1          1          일본
# 649      12,956,000          0      6,241          1          2          한국
# 650         606,000          0         95          1          2          한국
# 651               0          0          0          1          2          한국
# 652  12,051,537,000          0  1,649,429          1          1          한국
#
#     Unnamed: 11          Unnamed: 12
# 648          일본          (주)도키엔터테인먼트
# 649          한국                  NaN
# ...

# %%
df33["month"]="26.02"
df34["month"]="26.01"

# %%
df33.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df33.head()
# Out:
#   ranking movie_name release_date           sales sales_percentage  \
# 0       1   왕과 사는 남자   2026-02-04  73,493,037,620            62.0%
# 1       2        휴민트   2026-02-11  17,802,011,580            15.0%
# 2       3       신의악단   2025-12-31   4,901,114,260             4.1%
# 3       4     만약에 우리   2025-12-31   3,430,645,850             2.9%
# 4       5        넘버원   2026-02-11   2,523,309,980             2.1%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0   73,742,894,090  7,641,781           7,667,180        2,165    179,807
# 1   17,818,289,580  1,766,508           1,767,510        1,520     74,117
# 2   13,172,979,710    512,586           1,381,202          893     26,420
# 3   25,465,066,210    339,554           2,598,458          923     26,127
# 4    2,530,164,980    263,905             264,607          652     17,255
#
#   main_country country          distributor  month
# 0           한국      한국               (주)쇼박스  26.02
# ...

# %%
df34.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df34.head()
# Out:
#   ranking                movie_name release_date           sales  \
# 0       1                    만약에 우리   2025-12-31  20,926,257,000
# 1       2                 아바타: 불과 재   2025-12-17  25,385,921,530
# 2       3                    주토피아 2   2025-11-26   8,220,197,870
# 3       4                      신의악단   2025-12-31   8,075,984,490
# 4       5  오늘 밤, 세계에서 이 사랑이 사라진다 해도   2025-12-24   3,651,424,140
#
#   sales_percentage cumulative_sales   audience cumulative_audience  \
# 0            24.5%   22,034,420,360  2,129,768           2,258,904
# 1            29.7%   77,795,820,820  2,085,863           6,655,401
# 2             9.6%   82,344,813,470    850,524           8,556,229
# 3             9.5%    8,271,865,450    843,984             868,616
# 4             4.3%    8,332,960,890    370,974             859,995
#
#   screen_count show_count main_country country          distributor  month
# 0        1,116    101,286           한국      한국               (주)쇼박스  26.01
# ...

# %%
df = pd.concat([df34, df33])

# %%
df.head()
# Out:
#   ranking                movie_name release_date           sales  \
# 0       1                    만약에 우리   2025-12-31  20,926,257,000
# 1       2                 아바타: 불과 재   2025-12-17  25,385,921,530
# 2       3                    주토피아 2   2025-11-26   8,220,197,870
# 3       4                      신의악단   2025-12-31   8,075,984,490
# 4       5  오늘 밤, 세계에서 이 사랑이 사라진다 해도   2025-12-24   3,651,424,140
#
#   sales_percentage cumulative_sales   audience cumulative_audience  \
# 0            24.5%   22,034,420,360  2,129,768           2,258,904
# 1            29.7%   77,795,820,820  2,085,863           6,655,401
# 2             9.6%   82,344,813,470    850,524           8,556,229
# 3             9.5%    8,271,865,450    843,984             868,616
# 4             4.3%    8,332,960,890    370,974             859,995
#
#   screen_count show_count main_country country          distributor  month
# 0        1,116    101,286           한국      한국               (주)쇼박스  26.01
# ...

# %%
df.to_csv("260102.csv", index=False)

# %%
df=pd.read_csv("KOBIS_월별박스오피스_260304.csv")

# %%
df35 = df.iloc[7:717].reset_index(drop=True)
df35.head()
# Out:
#   ■ 월별 박스오피스      Unnamed: 1  Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0          1             살목지  2026-04-08  22,831,804,120      34.0%
# 1          2       프로젝트 헤일메리  2026-03-18  14,762,259,550      22.0%
# 2          3        왕과 사는 남자  2026-02-04   9,809,935,600      14.6%
# 3          4  악마는 프라다를 입는다 2  2026-04-29   2,237,609,510       3.3%
# 4          5              짱구  2026-04-22   2,152,603,650       3.2%
#
#         Unnamed: 5 Unnamed: 6  Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0   22,940,186,820  2,227,421   2,238,031      1,511    105,553          한국
# 1   28,848,591,520  1,318,796   2,553,517      1,401     77,027          미국
# 2  161,599,802,060  1,009,272  16,741,084      1,408     80,533          한국
# 3    2,237,609,510    253,206     253,206      1,578     12,371          미국
# 4    2,152,603,650    224,597     224,597        878     13,994          한국
#
#   Unnamed: 11               Unnamed: 12
# 0          한국                    (주)쇼박스
# ...

# %%
df35.tail()
# Out:
#     ■ 월별 박스오피스     Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 705        686         장가가는 길         NaN          0       0.0%          0
# 706        686            아버지         NaN          0       0.0%          0
# 707        686           시어머니         NaN          0       0.0%          0
# 708        686        비상 12.3         NaN          0       0.0%          0
# 709        686  뻐꾸기둥지위로 날아간 새  1977-09-17          0       0.0%          0
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 705          0          0          1          2          몽고          몽고
# 706          0          0          1          2          몽고          몽고
# 707          0          0          1          2          몽고          몽고
# 708          0          0          1          2          한국          한국
# 709          0          0          1          1          미국          미국
#
#     Unnamed: 12
# 705         NaN
# 706         NaN
# 707         NaN
# ...

# %%
df36 = df.iloc[722:-1].reset_index(drop=True)
df36.head()
# Out:
#   ■ 월별 박스오피스 Unnamed: 1  Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0          1   왕과 사는 남자  2026-02-04  78,046,972,370      68.4%
# 1          2  프로젝트 헤일메리  2026-03-18  14,086,331,970      12.3%
# 2          3        호퍼스  2026-03-04   7,017,060,940       6.2%
# 3          4        휴민트  2026-02-11   2,177,210,730       1.9%
# 4          5        삼악도  2026-03-11     850,819,000       0.7%
#
#         Unnamed: 5 Unnamed: 6  Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0  151,789,866,460  8,064,632  15,731,812      2,262    230,629          한국
# 1   14,086,331,970  1,234,721   1,234,721      1,350     53,409          미국
# 2    7,027,671,940    711,999     712,810      1,013     42,868          미국
# 3   19,995,500,310    213,864   1,981,374        784     16,907          한국
# 4      851,323,000     92,199      92,271        235      7,543          한국
#
#   Unnamed: 11               Unnamed: 12
# 0          한국                    (주)쇼박스
# 1          미국  소니픽쳐스엔터테인먼트코리아주식회사극장배급지점
# ...

# %%
df36.tail()
# Out:
#     ■ 월별 박스오피스       Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 583        569       어네스트와 셀레스틴  2014-02-20          0       0.0%
# 584        569      12명의 성난 사람들         NaN          0       0.0%
# 585        569          허공에의 질주         NaN          0       0.0%
# 586        569          플란다스의 개  2000-02-19          0       0.0%
# 587        569  그들은 피아노 연주자를 쐈다  2025-01-29          0       0.0%
#
#       Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 583  335,283,100          0     49,823          1          1         프랑스
# 584   10,520,000          0      4,075          1          1          미국
# 585    5,151,000          0        711          1          1          미국
# 586    4,668,200          0        638          1          1          한국
# 587   29,985,900          0      3,162          1          1         스페인
#
#     Unnamed: 11   Unnamed: 12
# 583         프랑스  씨너스엔터테인먼트(주)
# 584          미국           NaN
# 585          미국           NaN
# ...

# %%
df35["month"]="25.04"
df36["month"]="25.03"

# %%
df35.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df35.head()
# Out:
#   ranking      movie_name release_date           sales sales_percentage  \
# 0       1             살목지   2026-04-08  22,831,804,120            34.0%
# 1       2       프로젝트 헤일메리   2026-03-18  14,762,259,550            22.0%
# 2       3        왕과 사는 남자   2026-02-04   9,809,935,600            14.6%
# 3       4  악마는 프라다를 입는다 2   2026-04-29   2,237,609,510             3.3%
# 4       5              짱구   2026-04-22   2,152,603,650             3.2%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0   22,940,186,820  2,227,421           2,238,031        1,511    105,553
# 1   28,848,591,520  1,318,796           2,553,517        1,401     77,027
# 2  161,599,802,060  1,009,272          16,741,084        1,408     80,533
# 3    2,237,609,510    253,206             253,206        1,578     12,371
# 4    2,152,603,650    224,597             224,597          878     13,994
#
#   main_country country               distributor  month
# ...

# %%
df36.columns = [
    "ranking",
    "movie_name",
    "release_date",
    "sales",
    "sales_percentage",
    "cumulative_sales",
    "audience",
    "cumulative_audience",
    "screen_count",
    "show_count",
    "main_country",
    "country",
    "distributor", "month"
]
df36.head()
# Out:
#   ranking movie_name release_date           sales sales_percentage  \
# 0       1   왕과 사는 남자   2026-02-04  78,046,972,370            68.4%
# 1       2  프로젝트 헤일메리   2026-03-18  14,086,331,970            12.3%
# 2       3        호퍼스   2026-03-04   7,017,060,940             6.2%
# 3       4        휴민트   2026-02-11   2,177,210,730             1.9%
# 4       5        삼악도   2026-03-11     850,819,000             0.7%
#
#   cumulative_sales   audience cumulative_audience screen_count show_count  \
# 0  151,789,866,460  8,064,632          15,731,812        2,262    230,629
# 1   14,086,331,970  1,234,721           1,234,721        1,350     53,409
# 2    7,027,671,940    711,999             712,810        1,013     42,868
# 3   19,995,500,310    213,864           1,981,374          784     16,907
# 4      851,323,000     92,199              92,271          235      7,543
#
#   main_country country               distributor  month
# 0           한국      한국                    (주)쇼박스  25.03
# ...

# %%
df = pd.concat([df36, df35])

# %%
df.to_csv("260304.csv", index=False)
